# %%
import requests
import pandas as pd

# %%
min_rank = 1
max_rnk = 100
total = 1000
responses = []

# url = f"https://clinicaltrials.gov/api/query/full_studies?expr=COVID-19+AND+SEARCH%5BLocation%5D%28AREA%5BLocationCountry%5D+United+States%29&min_rnk={min_rank}&max_rnk={max_rnk}&fmt=json"
# response = requests.get(url)
# json = response.json()

try:
    while max_rnk < total:
        url = f"https://clinicaltrials.gov/api/query/full_studies?expr=COVID-19+AND+SEARCH%5BLocation%5D%28AREA%5BLocationCountry%5D+United+States%29&min_rnk={min_rank}&max_rnk={max_rnk}&fmt=json"
        response = requests.get(url)
        json = response.json()
        for rank in json['FullStudiesResponse']['FullStudies']:
            responses.append(rank)
        min_rank += 100
        max_rnk += 100
except:
    pass

# %%
len(responses)
# Out:
# 138

# %%
responses[0]
# Out:
# {'Rank': 1,
#  'Study': {'ProtocolSection': {'IdentificationModule': {'NCTId': 'NCT04349202',
#     'OrgStudyIdInfo': {'OrgStudyId': '2020-134'},
#     'Organization': {'OrgFullName': 'William Beaumont Hospitals',
#      'OrgClass': 'OTHER'},
#     'BriefTitle': 'Beaumont Health Large-scale Automated Serologic Testing for COVID-19',
#     'OfficialTitle': 'Beaumont Health Large-scale Automated Serologic Testing for COVID-19',
#     'Acronym': 'BLAST COVID-19'},
#    'StatusModule': {'StatusVerifiedDate': 'April 2020',
#     'OverallStatus': 'Recruiting',
#     'ExpandedAccessInfo': {'HasExpandedAccess': 'No'},
#     'StartDateStruct': {'StartDate': 'April 2020',
#      'StartDateType': 'Anticipated'},
#     'PrimaryCompletionDateStruct': {'PrimaryCompletionDate': 'June 2021',
#      'PrimaryCompletionDateType': 'Anticipated'},
#     'CompletionDateStruct': {'CompletionDate': 'June 2021',
#      'CompletionDateType': 'Anticipated'},
#     'StudyFirstSubmitDate': 'April 13, 2020',
#     'StudyFirstSubmitQCDate': 'April 13, 2020',
#     'StudyFirstPostDateStruct': {'StudyFirstPostDate': 'April 16, 2020',
#      'StudyFirstPostDateType': 'Actual'},
#     'LastUpdateSubmitDate': 'April 13, 2020',
#     'LastUpdatePostDateStruct': {'LastUpdatePostDate': 'April 16, 2020',
#      'LastUpdatePostDateType': 'Actual'}},
#    'SponsorCollaboratorsModule': {'ResponsibleParty': {'ResponsiblePartyType': 'Principal Investigator',
#      'ResponsiblePartyInvestigatorFullName': 'Matthew Sims, MD, PhD',
#      'ResponsiblePartyInvestigatorTitle': 'Director Infectious Disease Research, Beaumont Health; Professor of Internal Medicine and Foundational Medical Studies, OUWB School of Medicine',
#      'ResponsiblePartyInvestigatorAffiliation': 'William Beaumont Hospitals'},
#     'LeadSponsor': {'LeadSponsorName': 'William Beaumont Hospitals',
#      'LeadSponsorClass': 'OTHER'}},
#    'OversightModule': {'OversightHasDMC': 'No',
#     'IsFDARegulatedDrug': 'No',
#     'IsFDARegulatedDevice': 'Yes',
#     'IsUSExport': 'No'},
#    'ConditionsModule': {'ConditionList': {'Condition': ['COVID-19',
#       'Coronavirus Infection',
#       'Severe Acute Respiratory Syndrome Coronavirus 2']},
#     'KeywordList': {'Keyword': ['Exposure, Occupational',
#       'COVID-19 virus infection',
#       'COVID-19 pandemic',
#       'COVID-19 virus testing']}},
#    'DesignModule': {'StudyType': 'Observational',
#     'PatientRegistry': 'No',
#     'DesignInfo': {'DesignObservationalModelList': {'DesignObservationalModel': ['Cohort']},
#      'DesignTimePerspectiveList': {'DesignTimePerspective': ['Prospective']}},
#     'BioSpec': {'BioSpecRetention': 'Samples With DNA',
#      'BioSpecDescription': 'Whole blood and serum'},
#     'EnrollmentInfo': {'EnrollmentCount': '50000',
#      'EnrollmentType': 'Anticipated'}},
#    'ArmsInterventionsModule': {'ArmGroupList': {'ArmGroup': [{'ArmGroupLabel': 'Beaumont employees',
#        'ArmGroupDescription': 'Beaumont employees (employees and affiliated non-employed physicians and advanced practice providers) undergoing serology testing for SARS-CoV-2 antibodies',
#        'ArmGroupInterventionList': {'ArmGroupInterventionName': ['Diagnostic Test: EUROIMMUN assay']}}]},
#     'InterventionList': {'Intervention': [{'InterventionType': 'Diagnostic Test',
#        'InterventionName': 'EUROIMMUN assay',
#        'InterventionDescription': 'Serology testing to detect SARS-CoV-2 antibodies',
#        'InterventionArmGroupLabelList': {'InterventionArmGroupLabel': ['Beaumont employees']}}]}},
#    'OutcomesModule': {'PrimaryOutcomeList': {'PrimaryOutcome': [{'PrimaryOutcomeMeasure': 'Prevalence COVID antibodies in employees of Beaumont Health',
#        'PrimaryOutcomeDescription': 'Serology testing of Beaumont Health employees will allow an estimation of asymptomatic carriage and help determine level of nosocomial spread of COVID-19 within our institution among its employees. All participants will provide over 2 blood draws between 2 and 4 weeks apart to determine if they developed antibodies to COVID-19. Participants at medium risk for exposure in their job function at Beaumont will have 3 draws 2-4 weeks apart and people considered the highest risk, those who provide the direct patient care to COVID-19 patients, will be tested 2-4 weeks apart until the pandemic in Michigan is under control (estimated to be 8 blood draws).',
#        'PrimaryOutcomeTimeFrame': '1 year'}]}},
#    'EligibilityModule': {'EligibilityCriteria': 'Inclusion Criteria:\n\nAge ≥ 18 years\nBeaumont Health employees and affiliated non-employed physicians and advanced practice providers\n\nExclusion Criteria:\n\nDecisionally impaired',
#     'HealthyVolunteers': 'Accepts Healthy Volunteers',
#     'Gender': 'All',
#     'MinimumAge': '18 Years',
#     'StdAgeList': {'StdAge': ['Adult', 'Older Adult']},
#     'StudyPopulation': 'Beaumont Health Employees and affiliated non-employed physicians and advanced practice providers',
#     'SamplingMethod': 'Non-Probability Sample'},
#    'ContactsLocationsModule': {'CentralContactList': {'CentralContact': [{'CentralContactName': 'Maureen Cooney, RN, BSN',
#        'CentralContactRole': 'Contact',
#        'CentralContactPhone': '248-551-0099',
#        'CentralContactEMail': 'Maureen.Cooney@beaumont.org'},
#       {'CentralContactName': 'Matthew Sims, MD, PhD',
#        'CentralContactRole': 'Contact',
#        'CentralContactPhone': '248-551-0027',
#        'CentralContactEMail': 'Matthew.Sims@beaumont.edu'}]},
#     'OverallOfficialList': {'OverallOfficial': [{'OverallOfficialName': 'Matthew Sims, MD, PhD',
#        'OverallOfficialAffiliation': 'William Beaumont Hospitals',
#        'OverallOfficialRole': 'Principal Investigator'}]},
#     'LocationList': {'Location': [{'LocationFacility': 'Beaumont Health System',
#        'LocationStatus': 'Recruiting',
#        'LocationCity': 'Royal Oak',
#        'LocationState': 'Michigan',
#        'LocationZip': '48073',
#        'LocationCountry': 'United States'},
#       {'LocationFacility': 'Beaumont Health',
#        'LocationStatus': 'Not yet recruiting',
#        'LocationCity': 'Royal Oak',
#        'LocationState': 'Michigan',
#        'LocationZip': '48073',
#        'LocationCountry': 'United States',
#        'LocationContactList': {'LocationContact': [{'LocationContactName': 'Maureen Cooney, RN, BSN',
#           'LocationContactRole': 'Contact',
#           'LocationContactPhone': '248-551-0099',
#           'LocationContactEMail': 'Maureen.Cooney@beaumont.org'}]}}]}},
#    'IPDSharingStatementModule': {'IPDSharing': 'No'}},
#   'DerivedSection': {'MiscInfoModule': {'VersionHolder': 'April 17, 2020'},
#    'ConditionBrowseModule': {'ConditionMeshList': {'ConditionMesh': [{'ConditionMeshId': 'D000018352',
#        'ConditionMeshTerm': 'Coronavirus Infections'},
#       {'ConditionMeshId': 'D000045169',
#        'ConditionMeshTerm': 'Severe Acute Respiratory Syndrome'}]},
#     'ConditionAncestorList': {'ConditionAncestor': [{'ConditionAncestorId': 'D000003333',
#        'ConditionAncestorTerm': 'Coronaviridae Infections'},
#       {'ConditionAncestorId': 'D000030341',
#        'ConditionAncestorTerm': 'Nidovirales Infections'},
#       {'ConditionAncestorId': 'D000012327',
#        'ConditionAncestorTerm': 'RNA Virus Infections'},
#       {'ConditionAncestorId': 'D000014777',
#        'ConditionAncestorTerm': 'Virus Diseases'},
#       {'ConditionAncestorId': 'D000012141',
#        'ConditionAncestorTerm': 'Respiratory Tract Infections'},
#       {'ConditionAncestorId': 'D000012140',
#        'ConditionAncestorTerm': 'Respiratory Tract Diseases'}]},
#     'ConditionBrowseLeafList': {'ConditionBrowseLeaf': [{'ConditionBrowseLeafId': 'M14938',
#        'ConditionBrowseLeafName': 'Syndrome',
#        'ConditionBrowseLeafRelevance': 'low'},
#       {'ConditionBrowseLeafId': 'M19074',
#        'ConditionBrowseLeafName': 'Coronavirus Infections',
#        'ConditionBrowseLeafAsFound': 'Coronavirus',
#        'ConditionBrowseLeafRelevance': 'high'},
#       {'ConditionBrowseLeafId': 'M24032',
#        'ConditionBrowseLeafName': 'Severe Acute Respiratory Syndrome',
#        'ConditionBrowseLeafAsFound': 'Severe Acute Respiratory Syndrome',
#        'ConditionBrowseLeafRelevance': 'high'},
#       {'ConditionBrowseLeafId': 'M16105',
#        'ConditionBrowseLeafName': 'Virus Diseases',
#        'ConditionBrowseLeafRelevance': 'low'},
#       {'ConditionBrowseLeafId': 'M8866',
#        'ConditionBrowseLeafName': 'Infection',
#        'ConditionBrowseLeafRelevance': 'low'},
#       {'ConditionBrowseLeafId': 'M4951',
#        'ConditionBrowseLeafName': 'Communicable Diseases',
#        'ConditionBrowseLeafRelevance': 'low'},
#       {'ConditionBrowseLeafId': 'M13732',
#        'ConditionBrowseLeafName': 'RNA Virus Infections',
#        'ConditionBrowseLeafRelevance': 'low'},
#       {'ConditionBrowseLeafId': 'M13561',
#        'ConditionBrowseLeafName': 'Respiratory Tract Infections',
#        'ConditionBrowseLeafRelevance': 'low'},
#       {'ConditionBrowseLeafId': 'M13560',
#        'ConditionBrowseLeafName': 'Respiratory Tract Diseases',
#        'ConditionBrowseLeafRelevance': 'low'},
#       {'ConditionBrowseLeafId': 'T5212',
#        'ConditionBrowseLeafName': 'Severe Acute Respiratory Syndrome',
#        'ConditionBrowseLeafAsFound': 'Severe Acute Respiratory Syndrome',
#        'ConditionBrowseLeafRelevance': 'high'}]},
#     'ConditionBrowseBranchList': {'ConditionBrowseBranch': [{'ConditionBrowseBranchAbbrev': 'BC23',
#        'ConditionBrowseBranchName': 'Symptoms and General Pathology'},
#       {'ConditionBrowseBranchAbbrev': 'All',
#        'ConditionBrowseBranchName': 'All Conditions'},
#       {'ConditionBrowseBranchAbbrev': 'BC02',
#        'ConditionBrowseBranchName': 'Viral Diseases'},
#       {'ConditionBrowseBranchAbbrev': 'BC08',
#        'ConditionBrowseBranchName': 'Respiratory Tract (Lung and Bronchial) Diseases'},
#       {'ConditionBrowseBranchAbbrev': 'BC01',
#        'ConditionBrowseBranchName': 'Bacterial and Fungal Diseases'},
#       {'ConditionBrowseBranchAbbrev': 'Rare',
#        'ConditionBrowseBranchName': 'Rare Diseases'}]}}}}}

# %%
n = 0
list = []

for rank in responses:
    try:
        nctid = responses[n]["Study"]["ProtocolSection"]["IdentificationModule"]["NCTId"]
        brieftitle = responses[n]["Study"]["ProtocolSection"]["IdentificationModule"]["BriefTitle"]
        start_date = responses[n]["Study"]["ProtocolSection"]["StatusModule"]["StartDateStruct"]["StartDate"]
        completiondate = responses[n]["Study"]["ProtocolSection"]["StatusModule"]["CompletionDateStruct"]["CompletionDate"]
        overallstatus = responses[n]["Study"]["ProtocolSection"]["StatusModule"]["OverallStatus"]
        leadsponsor = responses[n]["Study"]["ProtocolSection"]["SponsorCollaboratorsModule"]["LeadSponsor"]["LeadSponsorName"]
        contactname = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["CentralContactList"]["CentralContact"][0]["CentralContactName"]
        contactphone = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["CentralContactList"]["CentralContact"][0]["CentralContactPhone"]
        contactemail = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["CentralContactList"]["CentralContact"][0]["CentralContactEMail"]
        interventiondesc = responses[n]["Study"]["ProtocolSection"]["ArmsInterventionsModule"]["InterventionList"]["Intervention"][0]["InterventionDescription"]
        briefsummary = responses[n]["Study"]["ProtocolSection"]["DescriptionModule"]["BriefSummary"]
        enrollmentcount = responses[n]["Study"]["ProtocolSection"]["DesignModule"]["EnrollmentInfo"]["EnrollmentCount"]
        primaryoutcomedesc = responses[n]["Study"]["ProtocolSection"]["OutcomesModule"]["PrimaryOutcomeList"]["PrimaryOutcome"][0]["PrimaryOutcomeMeasure"]
        facility = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["LocationList"]["Location"][0]["LocationFacility"]
        locationcity = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["LocationList"]["Location"][0]["LocationCity"]
        locationstate = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["LocationList"]["Location"][0]["LocationState"]
        locationzip = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["LocationList"]["Location"][0]["LocationZip"]
        locationcountry = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["LocationList"]["Location"][0]["LocationCountry"]
        dict = {"nctid":nctid,
               "brieftitle":brieftitle,
               "start_date":start_date,
               "completiondate":completiondate,
               "overallstatus":overallstatus,
               "leadsponsor":leadsponsor,
               "contactname":contactname,
               "contactphone": contactphone,
               "contactemail":contactemail,
               "interventiondesc":interventiondesc,
               "briefsummary":briefsummary,
               "enrollmentcount":enrollmentcount,
               "primaryoutcomedesc":primaryoutcomedesc,
               "facility":facility,
               "locationcity":locationcity,
               "locationstate":locationstate,
               "locationzip":locationzip,
               "locationcountry":locationcountry}
        list.append(dict)
        n+=1
    except:
        n+=1
        pass

# %%
len(list)
# Out:
# 101

# %%
covid_df = pd.DataFrame(list)

# %%
covid_df.head()
# Out:
#                                         briefsummary  \
# 0  The purpose of this study is to determine how ...
# 1  This study will compare two drugs (hydroxychlo...
# 2  This study will compare two drugs (hydroxychlo...
# 3  The objective of this study is to determine th...
# 4  Specific Aims:\n\nThe investigators will prosp...
#
#                                           brieftitle     completiondate  \
# 0  Beaumont Health Large-scale Automated Serologi...          June 2021
# 1  Hydroxychloroquine vs. Azithromycin for Hospit...  December 31, 2021
# 2  Hydroxychloroquine vs. Azithromycin for Outpat...  December 31, 2021
# 3  Bidirectional Oxygenation Valve in the Managem...           May 2020
# 4  Assessment of Exam Findings in Coronavirus Dis...       October 2020
#
#                   contactemail              contactname  contactphone  \
# 0  Maureen.Cooney@beaumont.org  Maureen Cooney, RN, BSN  248-551-0099
# 1      Valerie.Aston@imail.org     Valerie T Aston, MBA    8015074606
# 2      Valerie.Aston@imail.org     Valerie T Aston, MBA    8015074606
# 3     jeffrey.miller@emory.edu       Jeffrey Miller, MD  404-778-7200
# 4             yocum007@umn.edu        Matthew Yocum, MD  612-626-8015
#
#   enrollmentcount                                       facility  \
# 0           50000                         Beaumont Health System
# 1             300                   Intermountain Medical Center
# 2            1550                   Intermountain Medical Center
# 3               5                      Emory University Hospital
# 4             500  University of Minnesota Medical Center (UMMC)
#
#                                     interventiondesc  \
# 0   Serology testing to detect SARS-CoV-2 antibodies
# 1  Patients in the hydroxychloroquine arm will re...
# 2  Patients in the hydroxychloroquine arm will re...
# 3  The GO2 PEEP MOUTHPIECE has a bidirectional va...
# 4  The POCUS exam of the heart will capture 2 sta...
#
#                        leadsponsor locationcity locationcountry locationstate  \
# 0       William Beaumont Hospitals    Royal Oak   United States      Michigan
# 1  Intermountain Health Care, Inc.       Murray   United States          Utah
# 2  Intermountain Health Care, Inc.       Murray   United States          Utah
# 3                 Emory University      Atlanta   United States       Georgia
# 4          University of Minnesota  Minneapolis   United States     Minnesota
#
#   locationzip        nctid       overallstatus  \
# 0       48073  NCT04349202          Recruiting
# 1       84107  NCT04329832          Recruiting
# 2       84107  NCT04334382          Recruiting
# 3       30322  NCT04331366          Recruiting
# 4       55455  NCT04339998  Not yet recruiting
#
#                                   primaryoutcomedesc      start_date
# 0  Prevalence COVID antibodies in employees of Be...      April 2020
# 1            COVID Ordinal Outcomes Scale at 14 days  March 30, 2020
# 2       Hospitalization within 14 days of enrollment   April 2, 2020
# 3      Change in Oxygen Saturation by Pulse Oximetry   April 8, 2020
# 4                                POCUS Score - Lungs  April 15, 2020

# %%
covid_df.describe()
# Out:
#                                              briefsummary  \
# count                                                 101
# unique                                                101
# top     The primary objective of this study is to eval...
# freq                                                    1
#
#                                                brieftitle     completiondate  \
# count                                                 101                101
# unique                                                101                 61
# top     Colchicine Coronavirus SARS-CoV2 Trial (COLCOR...  December 31, 2021
# freq                                                    1                  6
#
#           contactemail                 contactname contactphone  \
# count              101                         101          101
# unique              93                          95           94
# top     estice@ori.org  Christopher Tignanelli, MD   2059079743
# freq                 2                           2            2
#
#        enrollmentcount                        facility  \
# count              101                             101
# unique              62                              85
# top                200  Massachusetts General Hospital
# freq                 5                               4
#
#                                interventiondesc              leadsponsor  \
# count                                       101                      101
# unique                                      100                       69
# top     Administered as an intravenous infusion  University of Minnesota
# freq                                          2                        5
#
#        locationcity locationcountry locationstate locationzip        nctid  \
# count           101             101           101         101          101
# unique           50               1            27          68          101
# top        New York   United States      New York       60637  NCT04292730
# freq             10             101            16           4            1
#
#        overallstatus primaryoutcomedesc  start_date
# count            101                101         101
# unique             2                 98          42
# top       Recruiting          Mortality  April 2020
# freq              66                  3          21

# %%
#check if there are Null cells in covid_df
covid_df.isnull().values.any()
# Out:
# False

# %%
# look at datatypes
# covid_df.dtypes

# %%
# remove day from start date column
covid_df['starting_date']=covid_df['start_date'].str.split(r'\s+').apply(lambda x: x[0:1] + x[2:] if len(x) > 2 else x).str.join(' ')
# covid_df
covid_df['completion_date']=covid_df['completiondate'].str.split(r'\s+').apply(lambda x: x[0:1] + x[2:] if len(x) > 2 else x).str.join(' ')

# drop initial date columns
covid_df = covid_df.drop(['start_date','completiondate' ], axis=1)
covid_df
# Out:
#                                           briefsummary  \
# 0    The purpose of this study is to determine how ...
# 1    This study will compare two drugs (hydroxychlo...
# 2    This study will compare two drugs (hydroxychlo...
# 3    The objective of this study is to determine th...
# 4    Specific Aims:\n\nThe investigators will prosp...
# 5    The purpose of this research study is to deter...
# 6    This current proposal evaluates the Longitudin...
# 7    Currently there are no US Food and Drug Admini...
# 8    This is a single arm phase IIa study of conval...
# 9    This study is a randomized, open label clinica...
# 10   Background: During the current COVID-19 pandem...
# 11   This is a Phase II interventional study testin...
# 12   Patients who are severely ill with COVID-19 ma...
# 13   Coronavirus disease 2019 (COVID-19) is an emer...
# 14   The purpose of this study is 1) to understand ...
# 15   This is an open label, phase 1 clinical trial ...
# 16   The purpose of this study is to assess the fea...
# 17   The goal of the research is to assess candidat...
# 18   There is significant interest throughout the U...
# 19   This study plans to learn more about the effec...
# 20   The purpose of this study is to test the hypot...
# 21   Coronavirus disease-2019 (COVID-19) has a quot...
# 22   The study aims to determine the safety and eff...
# 23   The PATCH trial (Prevention And Treatment of C...
# 24   The objective of the study is to assess the im...
# 25   This study aims to examine the tolerability of...
# 26   This is an international, multicenter, paralle...
# 27   This is a Phase II interventional study will t...
# 28   The study is designed as a randomized, placebo...
# 29   PRIORITY (Pregnancy CoRonavIrus Outcomes RegIs...
# ..                                                 ...
# 71   The viral Covid-19 outbreak is now considered ...
# 72   The purpose of the study is to develop a clini...
# 73   Severe acute respiratory syndrome (SARS-CoV2) ...
# 74   This is a phase I, open-label, dose ranging cl...
# 75   Primary Objective:\n\nTo assess the effect of ...
# 76   The primary objective of this study is to dete...
# 77   This Phase III trial four treatment strategies...
# 77   Hydroxychloroquine,Hydroxychloroquine,Azithrom...
# 78   Study of TJ003234 (Anti-GM-CSF Monoclonal Anti...
# 79   Losartan for Patients With COVID-19 Not Requir...
# 80   Pragmatic Factorial Trial of Hydroxychloroquin...
# 81   Intravenous Aviptadil for COVID-19 Associated ...
# 82   Do Angiotensin Receptor Blockers Mitigate Prog...
# 83                           COVID-19 Endoscopy Survey
# 84   BCG Vaccine for Health Care Workers as Defense...
# 85   A Study to Assess the Efficacy and Safety of G...
# 86   Early Extubation for Patients With Acute Hypox...
# 87   Post-exposure Prophylaxis / Preemptive Therapy...
# 88   Evaluation of the Efficacy and Safety of Saril...
# 89   Study to Evaluate the Safety and Antiviral Act...
# 90   Study to Evaluate the Safety and Antiviral Act...
# 91   A Study to Evaluate the Safety and Efficacy of...
# 92   Outcomes Related to COVID-19 Treated With Hydr...
# 93   Phase III DAS181 Lower Tract PIV Infection in ...
# 94            Adaptive COVID-19 Treatment Trial (ACTT)
# 95                       Rutgers COVID-19 Cohort Study
# 96   Project Health: Enhancing Effectiveness of a D...
# 97   Advocating for Supports to Improve Service Tra...
# 98   CROWN CORONATION: Chloroquine RepurpOsing to h...
# 99   Investigation of Metformin in Pre-Diabetes on ...
# 100  Target Engagement of a Novel Dissonance-Based ...
#
#                                           contactemail  \
# 0                          Maureen.Cooney@beaumont.org
# 1                              Valerie.Aston@imail.org
# 2                              Valerie.Aston@imail.org
# 3                             jeffrey.miller@emory.edu
# 4                                     yocum007@umn.edu
# 5                                  stevens.a@wustl.edu
# 6                             paul.wischmeyer@duke.edu
# 7                       nhank@prcresearcheducation.com
# 8             Mariefel.Vendivil@HackensackMeridian.org
# 9                                     tseto@queens.org
# 10                                     info@beat19.org
# 11                                 sabinehazan@aim.com
# 12                           CovidPlasma@jefferson.edu
# 13                                     Jie_Li@rush.edu
# 14                            erika.ratcliffe@duke.edu
# 15                                   msalathe@kumc.edu
# 16                        mlmadariaga@bsd.uchicago.edu
# 17                           drdon@neuroganicslabs.com
# 18   usaf.pentagon.11-mdg.mbx.flight-med-clinic@mai...
# 19                         bari-covid19@cuanschutz.edu
# 20                              eco7@cumc.columbia.edu
# 21                         pankti.reid@uchospitals.edu
# 22                                hwangph@stanford.edu
# 23              amelia.anderson@pennmedicine.upenn.edu
# 24                          sam.cammack@mountsinai.org
# 25                      rjan@medicine.bsd.uchicago.edu
# 26                            swindsor@saint-lukes.org
# 27                                 sabinehazan@aim.com
# 28                               pzheng@oncoimmune.com
# 29                            PRIORITYCOVID19@ucsf.edu
# ..                                                 ...
# 71                          victoria.vazquez@kcl.ac.uk
# 72                            brannock.robert@mayo.edu
# 73                              lberra@mgh.harvard.edu
# 74                                 KPWA.vaccine@kp.org
# 75                               Contact-US@sanofi.com
# 76                                whipcovid19@hfhs.org
# 77                                  mklebert@wustl.edu
# 78                          US.Info@I-MabBiopharma.com
# 79                                Covid19trial@umn.edu
# 80                             jason.stout@dm.duke.edu
# 81                          rbesthof@neurorxpharma.com
# 82                            kathryn.miller@sharp.com
# 83                               alboraie@azhar.edu.eg
# 84                              Andrew.Dinardo@Bcm.Edu
# 85                          arnaud.bastien@roivant.com
# 86                    bpatel@medicine.bsd.uchicago.edu
# 87                                     covid19@umn.edu
# 88                        clinicaltrials@regeneron.com
# 89                     GileadClinicalTrials@gilead.com
# 90                     GileadClinicalTrials@gilead.com
# 91              global-roche-genentech-trials@gene.com
# 92                           coldmixon@mgh.harvard.edu
# 93                              jho@ansunbiopharma.com
# 94                    DMIDClinicalTrials@niaid.nih.gov
# 95                          jeffrey.carson@rutgers.edu
# 96                                      estice@ori.org
# 97                             julie.l.taylor@vumc.org
# 98                                  lindayun@wustl.edu
# 99                             Gregory.Schwartz@va.gov
# 100                                     estice@ori.org
#
#                                            contactname  \
# 0                              Maureen Cooney, RN, BSN
# 1                                 Valerie T Aston, MBA
# 2                                 Valerie T Aston, MBA
# 3                                   Jeffrey Miller, MD
# 4                                    Matthew Yocum, MD
# 5                                       Angela Stevens
# 6            Paul E Wischmeyer, MD, EDIC, FASPEN, FCCM
# 7                          Nicole C Hank, PhD,MCR,MHSM
# 8                                    Mariefel Vendivil
# 9                                        Todd Seto, MD
# 10                                          BEAT19.org
# 11                                    Sabine Hazan, MD
# 12                                      Julie Karp, MD
# 13                                         Jie Li, PhD
# 14                                     Erika Ratcliffe
# 15                                Matthias Salathe, MD
# 16                           Maria Lucia Madariaga, MD
# 17                                Donald Cooper, Ph.D.
# 18                                 Scott A Wallace, MD
# 19                             Angela Rachubinski, PhD
# 20                          Elizabeth Oelsner, MD, MPH
# 21                                Pankti Reid, MD, MPH
# 22                                   Peter H Hwang, MD
# 23                                     Amelia Anderson
# 24                                         Sam Cammack
# 25                                  Reem Jan, MBBS BSc
# 26                                      Sheryl Windsor
# 27                                    Sabine Hazan, MD
# 28                                  Pan Zheng, MD, PhD
# 29                                      Ruth Gebrezghi
# ..                                                 ...
# 71                                    Victoria Vazquez
# 72                                     Robert Brannock
# 73                                   Lorenzo Berra, MD
# 74                             20-0003 Central Contact
# 75   Trial Transparency email recommended (Toll fre...
# 76                                    Dee Dee Wang, MD
# 77                             Michael Klebert, RN PhD
# 78                                        US Site Head
# 79                          Christopher Tignanelli, MD
# 80                                     Jason Stout, MD
# 81                               Robert E Besthof, MIM
# 82                                        Katie Miller
# 83                      Mohamed Alboraie, MD, MRCP(UK)
# 84                                  Andrew DiNardo, MD
# 85                                  Arnaud Bastien, MD
# 86                                    Bhakti Patel, MD
# 87              David Boulware (Please email), MD, MPH
# 88                       Clinical Trials Administrator
# 89            Gilead Clinical Study Information Center
# 90            Gilead Clinical Study Information Center
# 91   Reference Study ID Number: WA42380 www.roche.c...
# 92                                  Katie Oldmixon, RN
# 93                                    Jennifer Ho, M.D
# 94                             20-0006 Central Contact
# 95                                Jeffrey L Carson, MD
# 96                                 Eric M Stice, Ph.D.
# 97                            Julie Lounds Taylor, PhD
# 98                                       Linda Yun, BS
# 99                          Gregory G Schwartz, PhD MD
# 100                                    Eric Stice, PhD
#
#                   contactphone enrollmentcount  \
# 0                 248-551-0099           50000
# 1                   8015074606             300
# 2                   8015074606            1550
# 3                 404-778-7200               5
# 4                 612-626-8015             500
# 5                (314)362-6291             152
# 6                 919-681-6437             120
# 7                   4804716132              80
# 8                 551-996-5828              55
# 9                 808 354-3533             350
# 10              (415) 754-9290          100000
# 11                805-200-7426             600
# 12                215-503-4838            2000
# 13                312-947-0065             346
# 14                919-681-5006             100
# 15                  9135886000              50
# 16                773-270-2004              10
# 17                  7204313495             100
# 18                703-697-3255            1450
# 19              (720) 507-9107              80
# 20                212-305-9056            1600
# 21                  7737021220              50
# 22                650-725-6500              45
# 23                215-509-5690             400
# 24                212-824-8931            1000
# 25                734-972-7953              20
# 26                816-932-9858             900
# 27                805-200-7436             600
# 28               (202) 7516823             230
# 29              (415) 754-3749            1000
# ..                         ...             ...
# 71                 02071886765        10000000
# 72                904-953-2000             120
# 73                +16176437733             200
# 74                 12062872061              45
# 75                800-633-1610             210
# 76                313-574-2651            3000
# 77                314 747 1098             500
# 78                240-767-6981             144
# 79                612-624-4373             580
# 80                919-668-0826             500
# 81                +14842546134             120
# 82              (858) 939-7162             200
# 83              00201155019700              40
# 84                832-822-1038             700
# 85              (609)-410-2691             270
# 86                773-702-6800             108
# 87                  6126249996            3000
# 88                844-734-6643             400
# 89   1-833-445-3230 (GILEAD-0)            6000
# 90   1-833-445-3230 (GILEAD-0)            1600
# 91                888-662-6728             330
# 92                617 726-4777             510
# 93                858-452-2631             250
# 94                 13017617948             440
# 95                732-235-7122             750
# 96                541-484-2123             450
# 97                615-343-5659             180
# 98                314-273-2240           55000
# 99              (720) 723-6070            7868
# 100               541-484-2123             180
#
#                                               facility  \
# 0                               Beaumont Health System
# 1                         Intermountain Medical Center
# 2                         Intermountain Medical Center
# 3                            Emory University Hospital
# 4        University of Minnesota Medical Center (UMMC)
# 5                                                  BJC
# 6                        Duke University Medial Center
# 7                         Perseverance Research Center
# 8                 Hackensack University Medical Center
# 9                               Queen's Medical Center
# 10                                          BEAT19.org
# 11                                        ProgenaBiome
# 12                Thomas Jefferson University Hospital
# 13                      Rush University Medical Center
# 14                                     Duke University
# 15                 University of Kansas Medical Center
# 16                      University of Chicago Medicine
# 17                                         Neuroganics
# 18                                            Pentagon
# 19                      University of Colorado, Denver
# 20           Columbia University Irving Medical Center
# 21                      University of Chicago Medicine
# 22                                Stanford Health Care
# 23                          University of Pennsylvania
# 24             Icahn School of Medicine at Mount Sinai
# 25                               University of Chicago
# 26            Saint Luke's Mid America Heart Institute
# 27                                        ProgenaBiome
# 28   Institute of Human Virology, University of Mar...
# 29             University of California, San Francisco
# ..                                                 ...
# 71                      Massachusetts General Hospital
# 72                                 Mayo Clinic Florida
# 73                               University of Alabama
# 74              Emory Vaccine Center - The Hope Clinic
# 75                 Investigational Site Number 8400001
# 76                                 Henry Ford Hospital
# 77   Washington University School of Medicine Infec...
# 78         OSF Healthcare Saint Francis Medical Center
# 79                      Hennepin County Medical Center
# 80                              Duke Regional Hospital
# 81   Miller School of Medicine / University of Miam...
# 82                            Sharp Grossmont Hospital
# 83     Kings County Hospital Center, Brooklyn, NY, USA
# 84           Harvard T.H. Chan School of Public Health
# 85                                         Mount Sinai
# 86                University of Chicago Medical Center
# 87   Nationwide Enrollment via Internet, please ema...
# 88                                Regeneron Study Site
# 89   Kaiser Permanente Los Angeles Medical Center, ...
# 90   Kaiser Permanente Los Angeles Medical Center, ...
# 91                  University of California San Diego
# 92                               University of Arizona
# 93                          City of Hope cancer Center
# 94   University of Alabama at Birmingham School of ...
# 95   Clinical Research Center Rutgers-Robert Wood J...
# 96                           Oregon Research Institute
# 97          University of Illinois at Urbana-Champaign
# 98            Washington University School of Medicine
# 99          Phoenix VA Health Care System, Phoenix, AZ
# 100                                Stanford University
#
#                                       interventiondesc  \
# 0     Serology testing to detect SARS-CoV-2 antibodies
# 1    Patients in the hydroxychloroquine arm will re...
# 2    Patients in the hydroxychloroquine arm will re...
# 3    The GO2 PEEP MOUTHPIECE has a bidirectional va...
# 4    The POCUS exam of the heart will capture 2 sta...
# 5    Randomized to either fluvoxamine or placebo fo...
# 6    COVID-19 ICU patients will be measured using t...
# 7                                 200 mg PO BID 5 days
# 8    Fresh plasma will be infused one time to hospi...
# 9    oral tablet administered by hospital staff or ...
# 10   Participants will receive daily diary surveys ...
# 11                  Prophylaxis treatment for COVID-19
# 12   Previously infected COVID-19 patients will be ...
# 13   HFNC will be initiated at 50 L/min (AIRVO2 or ...
# 14   Crisis management coaching will be offered to ...
# 15   25 mg QD from day 0 to day 3. Dose escalation ...
# 16   Infusion of one unit of anti-SARS-CoV-2 conval...
# 17   An immunodiagnostic rapid (10-20 minute) test ...
# 18   Daily dosing of hydroxychloroquine as PrEP or PEP
# 19   Subjects will receive a 2 mg oral dose of bari...
# 20   Two tablets (400mg) twice daily on day 1; for ...
# 21   Group A: Tocilizumab (beginning dose 200mg) Si...
# 22   Two sprays to each nare of PVP-I 2% via nasal ...
# 23                               Antimalarial compound
# 24   This patch provides continuous real-time monit...
# 25   Tolerability study of HCQ 1200 mg administered...
# 26               Active Comparator: Dapagliflozin 10mg
# 27                   treatment with hydroxychloroquine
# 28                           CD24Fc is given on Day 1.
# 29   This is an observational study with no interve...
# ..                                                 ...
# 71                                     No Intervention
# 72    Analysis of volatile organic compounds in breath
# 73   80 ppm of inhaled nitric oxide for 48 hours, f...
# 74   Lipid nanoparticle (LNP) dispersion containing...
# 75   Pharmaceutical form:Tablet Route of administra...
# 76   The daily hydroxychloroquine treatment arm wil...
# 77                         anti-rheumatic drug (DMARD)
# 78                  patients receive a single infusion
# 79          Losartan; 25 mg daily; oral administration
# 80                                    Standard of care
# 81   Aviptadil by intravenous infusion + maximal in...
# 82   Standard of care plus the starting dose of los...
# 83   Physicians will report details of their endosc...
# 84   BCG vaccine will be administered by research n...
# 85   Gimsilumab is a fully human monoclonal antibod...
# 86   After application of the helmet, arterial bloo...
# 87   200mg tablet; 800 mg orally once, followed in ...
# 88           Single intravenous (IV) dose of sarilumab
# 89             Administered as an intravenous infusion
# 90             Administered as an intravenous infusion
# 6    Not yet recruiting  Metabolic and Nutritional Needs of COVID-19 Pa...
# 7            Recruiting                     Improvement of clinical status
# 8            Recruiting  For patients hospitalized for COVID-19 but not...
# 9            Recruiting                                 i. Clinical status
# 10           Recruiting                      Define Natural Symptom Course
# 11   Not yet recruiting  Prevention of COVID-19 measured by negative te...
# 12           Recruiting  Number of patients who screen eligible for don...
# 13   Not yet recruiting                                  Treatment failure
# 14   Not yet recruiting       Change in stress level as measured by survey
# 15           Recruiting  Number of participants with treatment-related ...
# 16           Recruiting  Feasibility of performing study pathway consis...
# 17           Recruiting  Clinical accuracy of the antibody-based rapid ...
# 18   Not yet recruiting                                          Incidence
# 19   Not yet recruiting  Phase 2: Cumulative incidence of Grade 3 and 4...
# 20   Not yet recruiting  Number of participants with symptomatic, lab-c...
# 21           Recruiting                                  Clinical response
# 22   Not yet recruiting          Mean change in viral titers of SARS-CoV-2
# 23           Recruiting                Median release from quarantine time
# 24   Not yet recruiting                    Number of different arrhythmias
# 25           Recruiting  Tolerability of high dose HCQ as measured by H...
# 26           Recruiting  Time to first occurrence of either death from ...
# 27   Not yet recruiting  Successful treatment as determined by Negative...
# 28           Recruiting             Improvement of COVID-19 disease status
# 29           Recruiting                              Clinical presentation
# ..                  ...                                                ...
# 71           Recruiting                           Physical health symptoms
# 72           Recruiting          Breath volatile organic compound profiles
# 73           Recruiting  Change of arterial oxygenation at 48 hours fro...
# 74           Recruiting  Frequency of solicited local reactogenicity ad...
# 75           Recruiting  Change from baseline to Day 3 in nasopharyngea...
# 76           Recruiting  Reduction in the number of COVID-19 infections...
# 77           Recruiting                                  Hours to recovery
# 78           Recruiting  Proportion (%) of subjects experiencing deteri...
# 79           Recruiting                                 Hospital Admission
# 80   Not yet recruiting  World Health Organization (WHO) ordinal scale ...
# 81   Not yet recruiting                                          Mortality
# 82           Recruiting                             Mechanical ventilation
# 83   Not yet recruiting  Effect of GI societies recommendations on prev...
# 84   Not yet recruiting  incidence (measured by confirmed positive test...
# 85           Recruiting                                   Primary endpoint
# 86   Not yet recruiting                                    ventilator days
# 87           Recruiting  Incidence of COVID19 Disease among those who a...
# 88           Recruiting  Percent change in C-reactive protein (CRP) levels
# 89           Recruiting  The Odds of Ratio for Improvement on a 7-point...
# 90           Recruiting  The Odds of Ratio for Improvement on a 7-point...
# 91           Recruiting  Clinical Status Assessed Using a 7-Category Or...
# 92           Recruiting             COVID Ordinal Outcomes Scale on Day 15
# 93           Recruiting  Percent of subjects who Return to Room Air (RT...
# 94           Recruiting  Percentage of subjects reporting each severity...
# 95           Recruiting                                         Prevalence
# 96           Recruiting                                           Body Fat
# 97           Recruiting  Change in Parental Knowledge about adult servi...
# 98   Not yet recruiting                               Symptomatic COVID-19
# 99           Recruiting  Time in days to death, non-fatal myocardial in...
# 100          Recruiting  Change in occurrences of binge eating episodes...
#
#       starting_date completion_date
# 0        April 2020       June 2021
# 1        March 2020   December 2021
# 2        April 2020   December 2021
# 3        April 2020        May 2020
# 4        April 2020    October 2020
# 5        April 2020       July 2020
# 6        April 2020   December 2020
# 7        April 2020  September 2020
# 8        April 2020      April 2021
# 9        March 2020   December 2021
# 10       March 2020      March 2022
# 11       April 2020       July 2021
# 12       April 2020      April 2021
# 13       April 2020       June 2020
# 14       April 2020       June 2020
# 15       March 2020    October 2020
# 16       April 2020   December 2021
# 17       April 2020      April 2021
# 18       April 2020     August 2020
# 19       April 2020    October 2020
# 20       March 2020      March 2022
# 21       April 2020   December 2020
# 22         May 2020     August 2020
# 23       April 2020   December 2021
# 24       April 2020      April 2021
# 25       April 2020       June 2020
# 26       April 2020   December 2020
# 27       April 2020       July 2021
# 28       April 2020        May 2022
# 29       March 2020      March 2024
# ..              ...             ...
# 71       March 2020      March 2022
# 72   September 2019   December 2021
# 73       March 2020      March 2022
# 74       March 2020       June 2021
# 75       March 2020        May 2020
# 76       April 2020      April 2021
# 77       April 2020     August 2021
# 78       April 2020  September 2020
# 79       April 2020      April 2021
# 80       April 2020     August 2020
# 81       April 2020  September 2020
# 82       March 2020   December 2020
# 83       April 2020   December 2020
# 84       April 2020   November 2021
# 85       April 2020    October 2020
# 86       April 2020       June 2021
# 87       March 2020        May 2020
# 88       March 2020      April 2021
# 89       March 2020        May 2020
# 90       March 2020        May 2020
# 91       April 2020  September 2021
# 92       April 2020       July 2021
# 93         May 2019   December 2021
# 94    February 2020      April 2023
# 95       April 2020    October 2021
# 96     October 2018       July 2023
# 97    December 2019        May 2024
# 98       April 2020   February 2021
# 99    February 2019     August 2024
# 100       July 2017       June 2022
#
# [101 rows x 18 columns]

# %%
import sqlalchemy as db

# %%
engine = db.create_engine('sqlite:///COVID-Clinical-Trials')
# connection = engine.connect()
metadata = db.MetaData()

covid_df.to_sql("COVID_ClinicalTrials", con=engine, if_exists="replace")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#
# OperationalError: too many SQL variables
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-20-3347b66e5864> in <module>()
#       3 metadata = db.MetaData()
#       4
# ----> 5 covid_df.to_sql("COVID_ClinicalTrials", con=engine, if_exists="replace")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2125         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2126                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2127                    dtype=dtype)
#    2128
#    2129     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1147                          schema=schema, dtype=dtype)
#    1148         table.create()
# -> 1149         table.insert(chunksize)
#    1150         if (not name.isdigit() and not name.islower()):
#    1151             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize)
#     661
#     662                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 663                 self._execute_insert(conn, keys, chunk_iter)
#     664
#     665     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     636         """Insert data into this table with database connection"""
#     637         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 638         conn.execute(*self.insert_statement(data, conn))
#     639
#     640     def insert(self, chunksize=None):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     505
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#     509     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) too many SQL variables [SQL: 'INSERT INTO "COVID_ClinicalTrials" ("index", briefsummary, brieftitle, contactemail, contactname, contactphone, enrollmentcount, facility, interventiondesc, leadsponsor, locationcity, locationcountry, locationstate, locationzip, nctid, overallstatus, primaryoutcomedesc, starting_date, completion_date) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?), (?, ?, ?, ?, ?,  ...
