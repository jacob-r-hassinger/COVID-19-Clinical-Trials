# %%
import requests
import pandas as pd
from datetime import date
import sqlalchemy as db

# %%
today = date.today()
dateval = today.strftime("%m/%d/%Y")
min_rank = 1
max_rnk = 100
total = 1000
responses = []

# url = f"https://clinicaltrials.gov/api/query/full_studies?expr=COVID-19+AND+SEARCH%5BLocation%5D%28AREA%5BLocationCountry%5D+United+States%29&min_rnk={min_rank}&max_rnk={max_rnk}&fmt=json"
# response = requests.get(url)
# json = response.json()

try:
    while max_rnk < total:
        url = f"https://clinicaltrials.gov/api/query/full_studies?expr=COVID-19+AND+SEARCH%5BLocation%5D%28AREA%5BLocationCountry%5D+United+States%29&min_rnk={min_rank}&max_rnk={max_rnk}&fmt=json"
        response = requests.get(url)
        json = response.json()
        for rank in json['FullStudiesResponse']['FullStudies']:
            responses.append(rank)
        min_rank += 100
        max_rnk += 100
except:
    pass

# %%
len(responses)
# Out:
# 194

# %%
responses[0]
# Out:
# {'Rank': 1,
#  'Study': {'ProtocolSection': {'IdentificationModule': {'NCTId': 'NCT04349202',
#     'OrgStudyIdInfo': {'OrgStudyId': '2020-134'},
#     'Organization': {'OrgFullName': 'William Beaumont Hospitals',
#      'OrgClass': 'OTHER'},
#     'BriefTitle': 'Beaumont Health Large-scale Automated Serologic Testing for COVID-19',
#     'OfficialTitle': 'Beaumont Health Large-scale Automated Serologic Testing for COVID-19',
#     'Acronym': 'BLAST COVID-19'},
#    'StatusModule': {'StatusVerifiedDate': 'April 2020',
#     'OverallStatus': 'Recruiting',
#     'ExpandedAccessInfo': {'HasExpandedAccess': 'No'},
#     'StartDateStruct': {'StartDate': 'April 2020',
#      'StartDateType': 'Anticipated'},
#     'PrimaryCompletionDateStruct': {'PrimaryCompletionDate': 'June 2021',
#      'PrimaryCompletionDateType': 'Anticipated'},
#     'CompletionDateStruct': {'CompletionDate': 'June 2021',
#      'CompletionDateType': 'Anticipated'},
#     'StudyFirstSubmitDate': 'April 13, 2020',
#     'StudyFirstSubmitQCDate': 'April 13, 2020',
#     'StudyFirstPostDateStruct': {'StudyFirstPostDate': 'April 16, 2020',
#      'StudyFirstPostDateType': 'Actual'},
#     'LastUpdateSubmitDate': 'April 13, 2020',
#     'LastUpdatePostDateStruct': {'LastUpdatePostDate': 'April 16, 2020',
#      'LastUpdatePostDateType': 'Actual'}},
#    'SponsorCollaboratorsModule': {'ResponsibleParty': {'ResponsiblePartyType': 'Principal Investigator',
#      'ResponsiblePartyInvestigatorFullName': 'Matthew Sims, MD, PhD',
#      'ResponsiblePartyInvestigatorTitle': 'Director Infectious Disease Research, Beaumont Health; Professor of Internal Medicine and Foundational Medical Studies, OUWB School of Medicine',
#      'ResponsiblePartyInvestigatorAffiliation': 'William Beaumont Hospitals'},
#     'LeadSponsor': {'LeadSponsorName': 'William Beaumont Hospitals',
#      'LeadSponsorClass': 'OTHER'}},
#    'OversightModule': {'OversightHasDMC': 'No',
#     'IsFDARegulatedDrug': 'No',
#     'IsFDARegulatedDevice': 'Yes',
#     'IsUSExport': 'No'},
#    'DescriptionModule': {'BriefSummary': "The purpose of this study is to determine how peoples' bodies respond to exposure to COVID-19. Employees of Beaumont Health in Michigan who are older than 18 years may be eligible to participate. Participants will have blood drawn two or more times for serology testing. This serology test will determine if participants have detectable levels of the antibodies that our bodies develop to fight COVID-19 infection. Participants will fill out a questionnaire each time they provide a blood sample. The questionnaires include questions about participants' personal traits; their health; general questions about their risk to exposure; job and risk of exposure; symptoms, diagnosis, treatment of COVID-19 since last blood draw. Researchers will monitor participants' medical records in a confidential manner for one year after the last blood draw to help determine if people who develop antibodies to COVID-19 are protected against developing a COVID-19 infection in the future.There may be no direct benefits for participants; however, information from this study may benefit other people by increasing our understanding of COVID-19, how it spreads from person to person, and how people respond to fight off the infection.The results of the serology test are used for research only and will not affect clinical decisions regarding participants' treatment or quarantine",
#     'DetailedDescription': "Beaumont Health is an eight-hospital regional health care system with a total of 3,337 beds, 38,000 employees and 5,000 physicians in Southeast Michigan. In the first 3 weeks of the COVID-19 pandemic within Michigan over 3300 patients tested positive through our system and over 1000 have been admitted for inpatient care. COVID-19 has a wide range of presentations from asymptomatic to multisystem organ failure and death. Spread from asymptomatic individuals has been described in the literature but the extent of this transmission is unclear. Large scale serologic testing can help address this question by detecting antibodies generated after an individual is infected with COVID-19. Healthcare workers have developed COVID-19 but the true infection rate among those who care for COVID-19 patients and whether the infection occurs at work is unknown.\n\nEvery day, thousands of Beaumont physicians, nurses, technicians and other caregivers are working under extraordinary stress, doing their very best to care for patients with this highly contagious and potentially deadly virus. They are trying to protect themselves from infection while dealing with personal protective equipment requirements and limited knowledge of who in the hospital environment may be carrying the infection and potentially spreading it among the staff. Caregivers are at greater risk of infection than the public, and when they become sick, it reduces the number of trained personnel available to care for hospitalized patients. Serological testing would give Beaumont's front-line staff and patients peace of mind by determining infection rates in our care units. Knowing the infection rates will demonstrate how effective the use of personal protective equipment has been for staff, whether any flaws exist in the system, and how many clinical staff currently have potentially protective antibodies.\n\nBeaumont Health has 2 EURO Lab Workstations capable of running the SARS-CoV-2 IgG and IgA EUROIMMUN serology assay (referred to as the EUROIMMUN assay hereafter). Each EUROIMMUN assay consists of 2 separate tests; one of which measures IgG (the memory antibody which should give long acting resistance to people who mount an immune response) and the second of which measures IgA (the secretory antibody that should protect against infection through mucous membranes). Researchers can run 5,000 samples a day with each sample being tested for IgA and IgG.\n\nPotential participants (employees and affiliated non-employed physicians and advanced practice providers) will provide informed consent. Researchers will analyze all participants over 2 blood draws between 2 and 4 weeks apart to see if they developed antibodies to COVID-19. Participants at medium risk for exposure in their job function at Beaumont will have 3 draws 2-4 weeks apart and people considered the highest risk, those who provide the direct patient care to COVID-19 patients, will be tested 2-4 weeks apart until the pandemic in Michigan is under control (estimated to be 8 blood draws). If the participants agree, researchers will bank 0.5 ml of serum for future testing related to COVID-19. An initial questionnaire and subsequent questionnaires with each blood draw will be completed by participants. Biostatistics will analyze the data from the questionnaires and the serology test to determine any links between level of risk associated with the participants job, medical history, and exposure history to development of COVID-19 antibodies. Participants medical records will be monitored for one year to see if they are diagnosed with COVID-19 and if they have a positive PCR test for COVID-19 since they were tested for the presence of antibodies. All employees identified as developing COVID-19 after their antibody levels were tested will be analyzed and a correlation between antibody level and development of COVID-19 will be generated. This will allow an estimation of the protective effect of antibodies r ...
#    'ConditionsModule': {'ConditionList': {'Condition': ['COVID-19',
#       'Coronavirus Infection',
#       'Severe Acute Respiratory Syndrome Coronavirus 2']},
#     'KeywordList': {'Keyword': ['Exposure, Occupational',
#       'COVID-19 virus infection',
#       'COVID-19 pandemic',
#       'COVID-19 virus testing']}},
#    'DesignModule': {'StudyType': 'Observational',
#     'PatientRegistry': 'No',
#     'DesignInfo': {'DesignObservationalModelList': {'DesignObservationalModel': ['Cohort']},
#      'DesignTimePerspectiveList': {'DesignTimePerspective': ['Prospective']}},
#     'BioSpec': {'BioSpecRetention': 'Samples With DNA',
#      'BioSpecDescription': 'Whole blood and serum'},
#     'EnrollmentInfo': {'EnrollmentCount': '50000',
#      'EnrollmentType': 'Anticipated'}},
#    'ArmsInterventionsModule': {'ArmGroupList': {'ArmGroup': [{'ArmGroupLabel': 'Beaumont employees',
#        'ArmGroupDescription': 'Beaumont employees (employees and affiliated non-employed physicians and advanced practice providers) undergoing serology testing for SARS-CoV-2 antibodies',
#        'ArmGroupInterventionList': {'ArmGroupInterventionName': ['Diagnostic Test: EUROIMMUN assay']}}]},
#     'InterventionList': {'Intervention': [{'InterventionType': 'Diagnostic Test',
#        'InterventionName': 'EUROIMMUN assay',
#        'InterventionDescription': 'Serology testing to detect SARS-CoV-2 antibodies',
#        'InterventionArmGroupLabelList': {'InterventionArmGroupLabel': ['Beaumont employees']}}]}},
#    'OutcomesModule': {'PrimaryOutcomeList': {'PrimaryOutcome': [{'PrimaryOutcomeMeasure': 'Prevalence COVID antibodies in employees of Beaumont Health',
#        'PrimaryOutcomeDescription': 'Serology testing of Beaumont Health employees will allow an estimation of asymptomatic carriage and help determine level of nosocomial spread of COVID-19 within our institution among its employees. All participants will provide over 2 blood draws between 2 and 4 weeks apart to determine if they developed antibodies to COVID-19. Participants at medium risk for exposure in their job function at Beaumont will have 3 draws 2-4 weeks apart and people considered the highest risk, those who provide the direct patient care to COVID-19 patients, will be tested 2-4 weeks apart until the pandemic in Michigan is under control (estimated to be 8 blood draws).',
#        'PrimaryOutcomeTimeFrame': '1 year'}]}},
#    'EligibilityModule': {'EligibilityCriteria': 'Inclusion Criteria:\n\nAge ≥ 18 years\nBeaumont Health employees and affiliated non-employed physicians and advanced practice providers\n\nExclusion Criteria:\n\nDecisionally impaired',
#     'HealthyVolunteers': 'Accepts Healthy Volunteers',
#     'Gender': 'All',
#     'MinimumAge': '18 Years',
#     'StdAgeList': {'StdAge': ['Adult', 'Older Adult']},
#     'StudyPopulation': 'Beaumont Health Employees and affiliated non-employed physicians and advanced practice providers',
#     'SamplingMethod': 'Non-Probability Sample'},
#    'ContactsLocationsModule': {'CentralContactList': {'CentralContact': [{'CentralContactName': 'Maureen Cooney, RN, BSN',
#        'CentralContactRole': 'Contact',
#        'CentralContactPhone': '248-551-0099',
#        'CentralContactEMail': 'Maureen.Cooney@beaumont.org'},
#       {'CentralContactName': 'Matthew Sims, MD, PhD',
#        'CentralContactRole': 'Contact',
#        'CentralContactPhone': '248-551-0027',
#        'CentralContactEMail': 'Matthew.Sims@beaumont.edu'}]},
#     'OverallOfficialList': {'OverallOfficial': [{'OverallOfficialName': 'Matthew Sims, MD, PhD',
#        'OverallOfficialAffiliation': 'William Beaumont Hospitals',
#        'OverallOfficialRole': 'Principal Investigator'}]},
#     'LocationList': {'Location': [{'LocationFacility': 'Beaumont Health System',
#        'LocationStatus': 'Recruiting',
#        'LocationCity': 'Royal Oak',
#        'LocationState': 'Michigan',
#        'LocationZip': '48073',
#        'LocationCountry': 'United States'},
#       {'LocationFacility': 'Beaumont Health',
#        'LocationStatus': 'Not yet recruiting',
#        'LocationCity': 'Royal Oak',
#        'LocationState': 'Michigan',
#        'LocationZip': '48073',
#        'LocationCountry': 'United States',
#        'LocationContactList': {'LocationContact': [{'LocationContactName': 'Maureen Cooney, RN, BSN',
#           'LocationContactRole': 'Contact',
#           'LocationContactPhone': '248-551-0099',
#           'LocationContactEMail': 'Maureen.Cooney@beaumont.org'}]}}]}},
#    'IPDSharingStatementModule': {'IPDSharing': 'No'}},
#   'DerivedSection': {'MiscInfoModule': {'VersionHolder': 'April 24, 2020'},
#    'ConditionBrowseModule': {'ConditionMeshList': {'ConditionMesh': [{'ConditionMeshId': 'D000018352',
#        'ConditionMeshTerm': 'Coronavirus Infections'},
#       {'ConditionMeshId': 'D000045169',
#        'ConditionMeshTerm': 'Severe Acute Respiratory Syndrome'}]},
#     'ConditionAncestorList': {'ConditionAncestor': [{'ConditionAncestorId': 'D000003333',
#        'ConditionAncestorTerm': 'Coronaviridae Infections'},
#       {'ConditionAncestorId': 'D000030341',
#        'ConditionAncestorTerm': 'Nidovirales Infections'},
#       {'ConditionAncestorId': 'D000012327',
#        'ConditionAncestorTerm': 'RNA Virus Infections'},
#       {'ConditionAncestorId': 'D000014777',
#        'ConditionAncestorTerm': 'Virus Diseases'},
#       {'ConditionAncestorId': 'D000012141',
#        'ConditionAncestorTerm': 'Respiratory Tract Infections'},
#       {'ConditionAncestorId': 'D000012140',
#        'ConditionAncestorTerm': 'Respiratory Tract Diseases'}]},
#     'ConditionBrowseLeafList': {'ConditionBrowseLeaf': [{'ConditionBrowseLeafId': 'M8866',
#        'ConditionBrowseLeafName': 'Infection',
#        'ConditionBrowseLeafRelevance': 'low'},
#       {'ConditionBrowseLeafId': 'M19074',
#        'ConditionBrowseLeafName': 'Coronavirus Infections',
#        'ConditionBrowseLeafAsFound': 'Coronavirus',
#        'ConditionBrowseLeafRelevance': 'high'},
#       {'ConditionBrowseLeafId': 'M24032',
#        'ConditionBrowseLeafName': 'Severe Acute Respiratory Syndrome',
#        'ConditionBrowseLeafAsFound': 'Severe Acute Respiratory Syndrome',
#        'ConditionBrowseLeafRelevance': 'high'},
#       {'ConditionBrowseLeafId': 'M14938',
#        'ConditionBrowseLeafName': 'Syndrome',
#        'ConditionBrowseLeafRelevance': 'low'},
#       {'ConditionBrowseLeafId': 'M4951',
#        'ConditionBrowseLeafName': 'Communicable Diseases',
#        'ConditionBrowseLeafRelevance': 'low'},
#       {'ConditionBrowseLeafId': 'M16105',
#        'ConditionBrowseLeafName': 'Virus Diseases',
#        'ConditionBrowseLeafRelevance': 'low'},
#       {'ConditionBrowseLeafId': 'M5138',
#        'ConditionBrowseLeafName': 'Coronaviridae Infections',
#        'ConditionBrowseLeafRelevance': 'low'},
#       {'ConditionBrowseLeafId': 'M13732',
#        'ConditionBrowseLeafName': 'RNA Virus Infections',
#        'ConditionBrowseLeafRelevance': 'low'},
#       {'ConditionBrowseLeafId': 'M13561',
#        'ConditionBrowseLeafName': 'Respiratory Tract Infections',
#        'ConditionBrowseLeafRelevance': 'low'},
#       {'ConditionBrowseLeafId': 'M13560',
#        'ConditionBrowseLeafName': 'Respiratory Tract Diseases',
#        'ConditionBrowseLeafRelevance': 'low'},
#       {'ConditionBrowseLeafId': 'T5212',
#        'ConditionBrowseLeafName': 'Severe Acute Respiratory Syndrome',
#        'ConditionBrowseLeafAsFound': 'Severe Acute Respiratory Syndrome',
#        'ConditionBrowseLeafRelevance': 'high'}]},
#     'ConditionBrowseBranchList': {'ConditionBrowseBranch': [{'ConditionBrowseBranchAbbrev': 'BC01',
#        'ConditionBrowseBranchName': 'Bacterial and Fungal Diseases'},
#       {'ConditionBrowseBranchAbbrev': 'All',
#        'ConditionBrowseBranchName': 'All Conditions'},
#       {'ConditionBrowseBranchAbbrev': 'BC02',
#        'ConditionBrowseBranchName': 'Viral Diseases'},
#       {'ConditionBrowseBranchAbbrev': 'BC08',
#        'ConditionBrowseBranchName': 'Respiratory Tract (Lung and Bronchial) Diseases'},
#       {'ConditionBrowseBranchAbbrev': 'BC23',
#        'ConditionBrowseBranchName': 'Symptoms and General Pathology'},
#       {'ConditionBrowseBranchAbbrev': 'Rare',
#        'ConditionBrowseBranchName': 'Rare Diseases'}]}}}}}

# %%
n = 0
main_list = []
intervention_list = []
phase_list = []

for rank in responses:
    try:
        nctid = responses[n]["Study"]["ProtocolSection"]["IdentificationModule"]["NCTId"]
        brieftitle = responses[n]["Study"]["ProtocolSection"]["IdentificationModule"]["BriefTitle"]
        start_date = responses[n]["Study"]["ProtocolSection"]["StatusModule"]["StartDateStruct"]["StartDate"]
        completiondate = responses[n]["Study"]["ProtocolSection"]["StatusModule"]["CompletionDateStruct"]["CompletionDate"]
        overallstatus = responses[n]["Study"]["ProtocolSection"]["StatusModule"]["OverallStatus"]
        leadsponsor = responses[n]["Study"]["ProtocolSection"]["SponsorCollaboratorsModule"]["LeadSponsor"]["LeadSponsorName"]
        contactname = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["CentralContactList"]["CentralContact"][0]["CentralContactName"]
        contactphone = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["CentralContactList"]["CentralContact"][0]["CentralContactPhone"]
        contactemail = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["CentralContactList"]["CentralContact"][0]["CentralContactEMail"]
        briefsummary = responses[n]["Study"]["ProtocolSection"]["DescriptionModule"]["BriefSummary"]
        enrollmentcount = responses[n]["Study"]["ProtocolSection"]["DesignModule"]["EnrollmentInfo"]["EnrollmentCount"]
        primaryoutcomedesc = responses[n]["Study"]["ProtocolSection"]["OutcomesModule"]["PrimaryOutcomeList"]["PrimaryOutcome"][0]["PrimaryOutcomeMeasure"]
        facility = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["LocationList"]["Location"][0]["LocationFacility"]
        locationcity = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["LocationList"]["Location"][0]["LocationCity"]
        locationstate = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["LocationList"]["Location"][0]["LocationState"]
        locationzip = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["LocationList"]["Location"][0]["LocationZip"]
        locationcountry = responses[n]["Study"]["ProtocolSection"]["ContactsLocationsModule"]["LocationList"]["Location"][0]["LocationCountry"]
        main_dict = {"nctid":nctid,
               "brieftitle":brieftitle,
               "start_date":start_date,
               "completiondate":completiondate,
               "overallstatus":overallstatus,
               "leadsponsor":leadsponsor,
               "contactname":contactname,
               "contactphone": contactphone,
               "contactemail":contactemail,
               "briefsummary":briefsummary,
               "enrollmentcount":enrollmentcount,
               "primaryoutcomedesc":primaryoutcomedesc,
               "facility":facility,
               "locationcity":locationcity,
               "locationstate":locationstate,
               "locationzip":locationzip,
               "locationcountry":locationcountry,
               "statusDate":dateval}
        main_list.append(main_dict)
        for intervention in responses[n]["Study"]["ProtocolSection"]["ArmsInterventionsModule"]["InterventionList"]["Intervention"]:
            interventionname = intervention["InterventionName"]
            interventiontype = intervention["InterventionType"]
            interventiondesc = intervention["InterventionDescription"]
            intervention_dict = {
                "nctid": nctid,
                "interventionname": interventionname,
                "interventiontype": interventiontype,
                "interventiondesc": interventiondesc,
                "statusDate": dateval}
            intervention_list.append(intervention_dict)
        try:
            for phase in responses[n]["Study"]["ProtocolSection"]["DesignModule"]["PhaseList"]["Phase"]:
                phase_dict = {
                    "nctid": nctid,
                    "phase": phase,
                    "statusDate": dateval
                }
                phase_list.append(phase_dict)
        except:
            pass
        n+=1
    except:
        n+=1
        pass

# %%
trials_found = len(main_list)
trials_found
# Out:
# 153

# %%
covid_df = pd.DataFrame(main_list)
intervention_df = pd.DataFrame(intervention_list)
phase_df = pd.DataFrame(phase_list)

# %%
covid_df.head()
# Out:
#          nctid                                         brieftitle  \
# 0  NCT04349202  Beaumont Health Large-scale Automated Serologi...
# 1  NCT04329832  Hydroxychloroquine vs. Azithromycin for Hospit...
# 2  NCT04334382  Hydroxychloroquine vs. Azithromycin for Outpat...
# 3  NCT04339998  Assessment of Exam Findings in Coronavirus Dis...
# 4  NCT04331366  Bidirectional Oxygenation Valve in the Managem...
#
#        start_date     completiondate       overallstatus  \
# 0      April 2020          June 2021          Recruiting
# 1  March 30, 2020  December 31, 2021          Recruiting
# 2   April 2, 2020  December 31, 2021          Recruiting
# 3  April 15, 2020       October 2020  Not yet recruiting
# 4   April 8, 2020           May 2020          Recruiting
#
#                        leadsponsor              contactname  contactphone  \
# 0       William Beaumont Hospitals  Maureen Cooney, RN, BSN  248-551-0099
# 1  Intermountain Health Care, Inc.     Valerie T Aston, MBA    8015074606
# 2  Intermountain Health Care, Inc.     Valerie T Aston, MBA    8015074606
# 3          University of Minnesota        Matthew Yocum, MD  612-626-8015
# 4                 Emory University       Jeffrey Miller, MD  404-778-7200
#
#                   contactemail  \
# 0  Maureen.Cooney@beaumont.org
# 1      Valerie.Aston@imail.org
# 2      Valerie.Aston@imail.org
# 3             yocum007@umn.edu
# 4     jeffrey.miller@emory.edu
#
#                                         briefsummary enrollmentcount  \
# 0  The purpose of this study is to determine how ...           50000
# 1  This study will compare two drugs (hydroxychlo...             300
# 2  This study will compare two drugs (hydroxychlo...            1550
# 3  Specific Aims:\n\nThe investigators will prosp...             500
# 4  The objective of this study is to determine th...               5
#
#                                   primaryoutcomedesc  \
# 0  Prevalence COVID antibodies in employees of Be...
# 1            COVID Ordinal Outcomes Scale at 14 days
# 2       Hospitalization within 14 days of enrollment
# 3                                POCUS Score - Lungs
# 4      Change in Oxygen Saturation by Pulse Oximetry
#
#                                         facility locationcity locationstate  \
# 0                         Beaumont Health System    Royal Oak      Michigan
# 1                   Intermountain Medical Center       Murray          Utah
# 2                   Intermountain Medical Center       Murray          Utah
# 3  University of Minnesota Medical Center (UMMC)  Minneapolis     Minnesota
# 4                      Emory University Hospital      Atlanta       Georgia
#
#   locationzip locationcountry  statusDate
# 0       48073   United States  04/26/2020
# 1       84107   United States  04/26/2020
# 2       84107   United States  04/26/2020
# 3       55455   United States  04/26/2020
# 4       30322   United States  04/26/2020

# %%
phase_df.head()
# Out:
#          nctid           phase  statusDate
# 0  NCT04329832         Phase 2  04/26/2020
# 1  NCT04334382         Phase 3  04/26/2020
# 2  NCT04331366  Not Applicable  04/26/2020
# 3  NCT04342663         Phase 2  04/26/2020
# 4  NCT04351243         Phase 2  04/26/2020

# %%
intervention_df.head()
# Out:
#          nctid    interventionname interventiontype  \
# 0  NCT04349202     EUROIMMUN assay  Diagnostic Test
# 1  NCT04329832  Hydroxychloroquine             Drug
# 2  NCT04329832        Azithromycin             Drug
# 3  NCT04334382  Hydroxychloroquine             Drug
# 4  NCT04334382        Azithromycin             Drug
#
#                                     interventiondesc  statusDate
# 0   Serology testing to detect SARS-CoV-2 antibodies  04/26/2020
# 1  Patients in the hydroxychloroquine arm will re...  04/26/2020
# 2  Patients in the azithromycin arm will receive ...  04/26/2020
# 3  Patients in the hydroxychloroquine arm will re...  04/26/2020
# 4  Patients in the azithromycin arm will receive ...  04/26/2020

# %%
covid_df.describe()
# Out:
#               nctid                  brieftitle  start_date completiondate  \
# count           153                         153         153            153
# unique          153                         152          54             89
# top     NCT04348370  COVID-19 Plasma Collection  April 2020     April 2021
# freq              1                           2          24             10
#
#        overallstatus            leadsponsor       contactname  contactphone  \
# count            153                    153               153           153
# unique             2                     97               144           143
# top       Recruiting  University of Chicago  Sabine Hazan, MD  541-484-2123
# freq             107                      6                 3             2
#
#           contactemail                                       briefsummary  \
# count              153                                                153
# unique             143                                                153
# top     estice@ori.org  Previous research has shown that high dose int...
# freq                 2                                                  1
#
#        enrollmentcount primaryoutcomedesc                        facility  \
# count              153                153                             153
# unique              77                150                             120
# top                500          Mortality  Massachusetts General Hospital
# freq                 9                  3                               6
#
#        locationcity locationstate locationzip locationcountry  statusDate
# count           153           153         153             153         153
# unique           57            28          89               2           1
# top        New York      New York       10032   United States  04/26/2020
# freq             15            22           6             152         153

# %%
#check if there are Null cells in covid_df
covid_df.isnull().values.any()
# Out:
# False

# %%
# look at datatypes
# covid_df.dtypes

# %%
# remove day from start date column
covid_df['starting_date']=covid_df['start_date'].str.split(r'\s+').apply(lambda x: x[0:1] + x[2:] if len(x) > 2 else x).str.join(' ')
# covid_df
covid_df['completion_date']=covid_df['completiondate'].str.split(r'\s+').apply(lambda x: x[0:1] + x[2:] if len(x) > 2 else x).str.join(' ')

# drop initial date columns
covid_df = covid_df.drop(['start_date','completiondate' ], axis=1)
covid_df
# Out:
#            nctid                                         brieftitle  \
# 0    NCT04349202  Beaumont Health Large-scale Automated Serologi...
# 1    NCT04329832  Hydroxychloroquine vs. Azithromycin for Hospit...
# 2    NCT04334382  Hydroxychloroquine vs. Azithromycin for Outpat...
# 3    NCT04339998  Assessment of Exam Findings in Coronavirus Dis...
# 4    NCT04331366  Bidirectional Oxygenation Valve in the Managem...
# ..           ...                                                ...
# 148  NCT04333732  CROWN CORONATION: Chloroquine RepurpOsing to h...
# 149  NCT04320472  Acute Encephalopathy in Critically Ill Patient...
# 150  NCT03323463  Major De-escalation to 30 Gy for Select Human ...
# 151  NCT02915198  Investigation of Metformin in Pre-Diabetes on ...
# 152  NCT03261050  Target Engagement of a Novel Dissonance-Based ...
#
#           overallstatus                               leadsponsor  \
# 0            Recruiting                William Beaumont Hospitals
# 1            Recruiting           Intermountain Health Care, Inc.
# 2            Recruiting           Intermountain Health Care, Inc.
# 3    Not yet recruiting                   University of Minnesota
# 4            Recruiting                          Emory University
# ..                  ...                                       ...
# 148  Not yet recruiting  Washington University School of Medicine
# 149          Recruiting                               Ictal Group
# 150          Recruiting    Memorial Sloan Kettering Cancer Center
# 151          Recruiting     VA Office of Research and Development
# 152          Recruiting                 Oregon Research Institute
#
#                     contactname    contactphone  \
# 0       Maureen Cooney, RN, BSN    248-551-0099
# 1          Valerie T Aston, MBA      8015074606
# 2          Valerie T Aston, MBA      8015074606
# 3             Matthew Yocum, MD    612-626-8015
# 4            Jeffrey Miller, MD    404-778-7200
# ..                          ...             ...
# 148               Linda Yun, BS    314-273-2240
# 149   Stephane LEGRIEL, MD, PhD     33139638839
# 150               Nancy Lee, MD    212-639-3341
# 151  Gregory G Schwartz, PhD MD  (720) 723-6070
# 152             Eric Stice, PhD    541-484-2123
#
#                          contactemail  \
# 0         Maureen.Cooney@beaumont.org
# 1             Valerie.Aston@imail.org
# 2             Valerie.Aston@imail.org
# 3                    yocum007@umn.edu
# 4            jeffrey.miller@emory.edu
# ..                                ...
# 148                lindayun@wustl.edu
# 149  neurocovid19study@ictalgroup.org
# 150                   leen2@mskcc.org
# 151           Gregory.Schwartz@va.gov
# 152                    estice@ori.org
#
#                                           briefsummary enrollmentcount  \
# 0    The purpose of this study is to determine how ...           50000
# 1    This study will compare two drugs (hydroxychlo...             300
# 2    This study will compare two drugs (hydroxychlo...            1550
# 3    Specific Aims:\n\nThe investigators will prosp...             500
# 4    The objective of this study is to determine th...               5
# ..                                                 ...             ...
# 148  Healthcare workers are at the frontline of the...           55000
# 149  Infection with SARS-CoV-2 or severe acute resp...             250
# 150  The purpose of this study is to demonstrate th...             300
# 151  This research will help us to learn if the med...            7868
# 152  Most people with an eating disorder (ED) do no...             180
#
#                                     primaryoutcomedesc  \
# 0    Prevalence COVID antibodies in employees of Be...
# 1              COVID Ordinal Outcomes Scale at 14 days
# 2         Hospitalization within 14 days of enrollment
# 3                                  POCUS Score - Lungs
# 4        Change in Oxygen Saturation by Pulse Oximetry
# ..                                                 ...
# 148                               Symptomatic COVID-19
# 149                                         prevalence
# 150  Effectiveness of study treatment for participa...
# 151  Time in days to death, non-fatal myocardial in...
# 152  Change in occurrences of binge eating episodes...
#
#                                               facility   locationcity  \
# 0                               Beaumont Health System      Royal Oak
# 1                         Intermountain Medical Center         Murray
# 2                         Intermountain Medical Center         Murray
# 3        University of Minnesota Medical Center (UMMC)    Minneapolis
# 4                            Emory University Hospital        Atlanta
# ..                                                 ...            ...
# 148           Washington University School of Medicine    Saint Louis
# 149  Jackson Memorial Health System; University of ...          Miami
# 150              Memoral Sloan Kettering Basking Ridge  Basking Ridge
# 151         Phoenix VA Health Care System, Phoenix, AZ        Phoenix
# 152                                Stanford University       Stanford
#
#     locationstate locationzip locationcountry  statusDate  starting_date  \
# 0        Michigan       48073   United States  04/26/2020     April 2020
# 1            Utah       84107   United States  04/26/2020     March 2020
# 2            Utah       84107   United States  04/26/2020     April 2020
# 3       Minnesota       55455   United States  04/26/2020     April 2020
# 4         Georgia       30322   United States  04/26/2020     April 2020
# ..            ...         ...             ...         ...            ...
# 148      Missouri       63110   United States  04/26/2020     April 2020
# 149       Florida       33136   United States  04/26/2020     March 2020
# 150    New Jersey       07920   United States  04/26/2020   October 2017
# 151       Arizona       85012   United States  04/26/2020  February 2019
# 152    California       94305   United States  04/26/2020      July 2017
#
#     completion_date
# 0         June 2021
# 1     December 2021
# 2     December 2021
# 3      October 2020
# 4          May 2020
# ..              ...
# 148   February 2021
# 149   December 2020
# 150    October 2021
# 151     August 2024
# 152       June 2022
#
# [153 rows x 18 columns]

# %%
engine = db.create_engine('sqlite:///COVID-Clinical-Trials.sqlite')

metadata = db.MetaData()

covid_df.to_sql("COVID_ClinicalTrials", con=engine, if_exists="replace")
intervention_df.to_sql("Interventions", con=engine, if_exists="replace")
phase_df.to_sql("Phase_Recordings", con=engine, if_exists="replace")

# %%
connection = engine.connect()
loclist = connection.execute("SELECT DISTINCT locationcity, locationstate, locationzip FROM COVID_ClinicalTrials")

# %%
loclist

# %%
d, a = {}, []
for rowproxy in loclist:
    # rowproxy.items() returns an array like [(key0, value0), (key1, value1)] > thank you stackoverflow!
    for column, value in rowproxy.items():
        # build up the dictionary
        d = {**d, **{column: value}}
    a.append(d)
connection.close()
a
# Out:
# [{'locationcity': 'Royal Oak',
#   'locationstate': 'Michigan',
#   'locationzip': '48073'},
#  {'locationcity': 'Murray', 'locationstate': 'Utah', 'locationzip': '84107'},
#  {'locationcity': 'Minneapolis',
#   'locationstate': 'Minnesota',
#   'locationzip': '55455'},
#  {'locationcity': 'Atlanta',
#   'locationstate': 'Georgia',
#   'locationzip': '30322'},
#  {'locationcity': 'Belleville',
#   'locationstate': 'Illinois',
#   'locationzip': '62220'},
#  {'locationcity': 'New York',
#   'locationstate': 'New York',
#   'locationzip': '10029'},
#  {'locationcity': 'Austin', 'locationstate': 'Texas', 'locationzip': '78705'},
#  {'locationcity': 'Durham',
#   'locationstate': 'North Carolina',
#   'locationzip': '27710'},
#  {'locationcity': 'Scottsdale',
#   'locationstate': 'Arizona',
#   'locationzip': '85254'},
#  {'locationcity': 'Hackensack',
#   'locationstate': 'New Jersey',
#   'locationzip': '07601'},
#  {'locationcity': 'Honolulu',
#   'locationstate': 'Hawaii',
#   'locationzip': '96813'},
#  {'locationcity': 'San Francisco',
#   'locationstate': 'California',
#   'locationzip': '94022'},
#  {'locationcity': 'Chicago',
#   'locationstate': 'Illinois',
#   'locationzip': '60452'},
#  {'locationcity': 'Philadelphia',
#   'locationstate': 'Pennsylvania',
#   'locationzip': '19107'},
#  {'locationcity': 'Chicago',
#   'locationstate': 'Illinois',
#   'locationzip': '60637'},
#  {'locationcity': 'Kansas City',
#   'locationstate': 'Kansas',
#   'locationzip': '66160'},
#  {'locationcity': 'Northglenn',
#   'locationstate': 'Colorado',
#   'locationzip': '80260'},
#  {'locationcity': 'Seattle',
#   'locationstate': 'Washington',
#   'locationzip': '98195'},
#  {'locationcity': 'Aurora',
#   'locationstate': 'Colorado',
#   'locationzip': '80045'},
#  {'locationcity': 'New York',
#   'locationstate': 'New York',
#   'locationzip': '10032'},
#  {'locationcity': 'New York',
#   'locationstate': 'New York',
#   'locationzip': '10022'},
#  {'locationcity': 'Nashville',
#   'locationstate': 'Tennessee',
#   'locationzip': '37232'},
#  {'locationcity': 'Stanford',
#   'locationstate': 'California',
#   'locationzip': '94305'},
#  {'locationcity': 'Philadelphia',
#   'locationstate': 'Pennsylvania',
#   'locationzip': '19104'},
#  {'locationcity': 'Scottsdale',
#   'locationstate': 'Arizona',
#   'locationzip': '85258'},
#  {'locationcity': 'Houston', 'locationstate': 'Texas', 'locationzip': '77027'},
#  {'locationcity': 'Bethesda',
#   'locationstate': 'Maryland',
#   'locationzip': '20892'},
#  {'locationcity': 'Kansas City',
#   'locationstate': 'Missouri',
#   'locationzip': '64111'},
#  {'locationcity': 'Ventura',
#   'locationstate': 'California',
#   'locationzip': '93003'},
#  {'locationcity': 'Boston',
#   'locationstate': 'Massachusetts',
#   'locationzip': '02114'},
#  {'locationcity': 'New York',
#   'locationstate': 'New York',
#   'locationzip': '10016'},
#  {'locationcity': 'San Francisco',
#   'locationstate': 'California',
#   'locationzip': '94143'},
#  {'locationcity': 'Saint Louis',
#   'locationstate': 'Missouri',
#   'locationzip': '63110'},
#  {'locationcity': 'Boston',
#   'locationstate': 'Massachusetts',
#   'locationzip': '02114-2621'},
#  {'locationcity': 'New Orleans',
#   'locationstate': 'Louisiana',
#   'locationzip': '70121'},
#  {'locationcity': 'Nashville',
#   'locationstate': 'Tennessee',
#   'locationzip': '37203'},
#  {'locationcity': 'Bronx',
#   'locationstate': 'New York',
#   'locationzip': '10467'},
#  {'locationcity': 'Los Angeles',
#   'locationstate': 'California',
#   'locationzip': '90095'},
#  {'locationcity': 'Winston-Salem',
#   'locationstate': 'North Carolina',
#   'locationzip': '27157'},
#  {'locationcity': 'New Orleans',
#   'locationstate': 'Louisiana',
#   'locationzip': '70112'},
#  {'locationcity': 'Seattle',
#   'locationstate': 'Washington',
#   'locationzip': '98133'},
#  {'locationcity': 'Cincinnati',
#   'locationstate': 'Ohio',
#   'locationzip': '45267'},
#  {'locationcity': 'Mineola',
#   'locationstate': 'New York',
#   'locationzip': '11501'},
#  {'locationcity': 'Indianapolis',
#   'locationstate': 'Indiana',
#   'locationzip': '46237'},
#  {'locationcity': 'Miami', 'locationstate': 'Florida', 'locationzip': '33136'},
#  {'locationcity': 'Birmingham',
#   'locationstate': 'Alabama',
#   'locationzip': '35222'},
#  {'locationcity': 'Baltimore',
#   'locationstate': 'Maryland',
#   'locationzip': '21287'},
#  {'locationcity': 'Hartford',
#   'locationstate': 'Connecticut',
#   'locationzip': '06105'},
#  {'locationcity': 'Cooperstown',
#   'locationstate': 'New York',
#   'locationzip': '13326'},
#  {'locationcity': 'Mobile',
#   'locationstate': 'Alabama',
#   'locationzip': '36604'},
#  {'locationcity': 'Richmond',
#   'locationstate': 'Virginia',
#   'locationzip': '23249'},
#  {'locationcity': 'Seattle',
#   'locationstate': 'Washington',
#   'locationzip': '98104'},
#  {'locationcity': 'New York',
#   'locationstate': 'New York',
#   'locationzip': '11042'},
#  {'locationcity': 'San Francisco',
#   'locationstate': 'California',
#   'locationzip': '94110'},
#  {'locationcity': 'Salt Lake City',
#   'locationstate': 'Utah',
#   'locationzip': '84108'},
#  {'locationcity': 'Phoenix',
#   'locationstate': 'Arizona',
#   'locationzip': '85006'},
#  {'locationcity': 'Saint Petersburg',
#   'locationstate': 'Florida',
#   'locationzip': '33701'},
#  {'locationcity': 'Los Angeles',
#   'locationstate': 'California',
#   'locationzip': '90048'},
#  {'locationcity': 'Chicago',
#   'locationstate': 'Illinois',
#   'locationzip': '60612'},
#  {'locationcity': 'Houston', 'locationstate': 'Texas', 'locationzip': '77030'},
#  {'locationcity': 'Boston',
#   'locationstate': 'Massachusetts',
#   'locationzip': '02115'},
#  {'locationcity': 'Stony Brook',
#   'locationstate': 'New York',
#   'locationzip': '11794'},
#  {'locationcity': 'Birmingham',
#   'locationstate': 'Alabama',
#   'locationzip': '35233'},
#  {'locationcity': 'Salt Lake City',
#   'locationstate': 'Utah',
#   'locationzip': '84132'},
#  {'locationcity': 'Durham',
#   'locationstate': 'North Carolina',
#   'locationzip': '27701'},
#  {'locationcity': 'Chicago',
#   'locationstate': 'Illinois',
#   'locationzip': '60616'},
#  {'locationcity': 'New Brunswick',
#   'locationstate': 'New Jersey',
#   'locationzip': '08901'},
#  {'locationcity': 'Boston',
#   'locationstate': 'Massachusetts',
#   'locationzip': '02132'},
#  {'locationcity': 'Durham',
#   'locationstate': 'North Carolina',
#   'locationzip': '27713'},
#  {'locationcity': 'Kansas City',
#   'locationstate': 'Missouri',
#   'locationzip': '64114'},
#  {'locationcity': 'Minneapolis',
#   'locationstate': 'Minnesota',
#   'locationzip': '55415'},
#  {'locationcity': 'Detroit',
#   'locationstate': 'Michigan',
#   'locationzip': '48202'},
#  {'locationcity': 'Jacksonville',
#   'locationstate': 'Florida',
#   'locationzip': '32224'},
#  {'locationcity': 'Birmingham',
#   'locationstate': 'Alabama',
#   'locationzip': '35294'},
#  {'locationcity': 'Decatur',
#   'locationstate': 'Georgia',
#   'locationzip': '30030-1705'},
#  {'locationcity': 'Durham',
#   'locationstate': 'North Carolina',
#   'locationzip': '27704'},
#  {'locationcity': 'La Mesa',
#   'locationstate': 'California',
#   'locationzip': '91942'},
#  {'locationcity': 'Tampa', 'locationstate': 'Florida', 'locationzip': '33606'},
#  {'locationcity': 'Peoria',
#   'locationstate': 'Illinois',
#   'locationzip': '61637'},
#  {'locationcity': 'Albertson',
#   'locationstate': 'New York',
#   'locationzip': '11507'},
#  {'locationcity': 'Jacksonville',
#   'locationstate': 'Florida',
#   'locationzip': '32207'},
#  {'locationcity': 'Anaheim',
#   'locationstate': 'California',
#   'locationzip': '92806'},
#  {'locationcity': 'La Jolla',
#   'locationstate': 'California',
#   'locationzip': '92093'},
#  {'locationcity': 'Tucson',
#   'locationstate': 'Arizona',
#   'locationzip': '85721'},
#  {'locationcity': 'Duarte',
#   'locationstate': 'California',
#   'locationzip': '91010'},
#  {'locationcity': 'Eugene', 'locationstate': 'Oregon', 'locationzip': '97403'},
#  {'locationcity': 'Chicago',
#   'locationstate': 'Illinois',
#   'locationzip': '60007'},
#  {'locationcity': 'Basking Ridge',
#   'locationstate': 'New Jersey',
#   'locationzip': '07920'},
#  {'locationcity': 'Phoenix',
#   'locationstate': 'Arizona',
#   'locationzip': '85012'}]

# %%
a[0]["locationzip"]
a[0]["locationcity"]
querylist, mainziplist = [], []

for n in a:
    querylist.append(f"{n['locationcity']}, {n['locationstate']} {n['locationzip']}")
    mainziplist.append(n["locationzip"])
querylist
# Out:
# ['Royal Oak, Michigan 48073',
#  'Murray, Utah 84107',
#  'Minneapolis, Minnesota 55455',
#  'Atlanta, Georgia 30322',
#  'Belleville, Illinois 62220',
#  'New York, New York 10029',
#  'Austin, Texas 78705',
#  'Durham, North Carolina 27710',
#  'Scottsdale, Arizona 85254',
#  'Hackensack, New Jersey 07601',
#  'Honolulu, Hawaii 96813',
#  'San Francisco, California 94022',
#  'Chicago, Illinois 60452',
#  'Philadelphia, Pennsylvania 19107',
#  'Chicago, Illinois 60637',
#  'Kansas City, Kansas 66160',
#  'Northglenn, Colorado 80260',
#  'Seattle, Washington 98195',
#  'Aurora, Colorado 80045',
#  'New York, New York 10032',
#  'New York, New York 10022',
#  'Nashville, Tennessee 37232',
#  'Stanford, California 94305',
#  'Philadelphia, Pennsylvania 19104',
#  'Scottsdale, Arizona 85258',
#  'Houston, Texas 77027',
#  'Bethesda, Maryland 20892',
#  'Kansas City, Missouri 64111',
#  'Ventura, California 93003',
#  'Boston, Massachusetts 02114',
#  'New York, New York 10016',
#  'San Francisco, California 94143',
#  'Saint Louis, Missouri 63110',
#  'Boston, Massachusetts 02114-2621',
#  'New Orleans, Louisiana 70121',
#  'Nashville, Tennessee 37203',
#  'Bronx, New York 10467',
#  'Los Angeles, California 90095',
#  'Winston-Salem, North Carolina 27157',
#  'New Orleans, Louisiana 70112',
#  'Seattle, Washington 98133',
#  'Cincinnati, Ohio 45267',
#  'Mineola, New York 11501',
#  'Indianapolis, Indiana 46237',
#  'Miami, Florida 33136',
#  'Birmingham, Alabama 35222',
#  'Baltimore, Maryland 21287',
#  'Hartford, Connecticut 06105',
#  'Cooperstown, New York 13326',
#  'Mobile, Alabama 36604',
#  'Richmond, Virginia 23249',
#  'Seattle, Washington 98104',
#  'New York, New York 11042',
#  'San Francisco, California 94110',
#  'Salt Lake City, Utah 84108',
#  'Phoenix, Arizona 85006',
#  'Saint Petersburg, Florida 33701',
#  'Los Angeles, California 90048',
#  'Chicago, Illinois 60612',
#  'Houston, Texas 77030',
#  'Boston, Massachusetts 02115',
#  'Stony Brook, New York 11794',
#  'Birmingham, Alabama 35233',
#  'Salt Lake City, Utah 84132',
#  'Durham, North Carolina 27701',
#  'Chicago, Illinois 60616',
#  'New Brunswick, New Jersey 08901',
#  'Boston, Massachusetts 02132',
#  'Durham, North Carolina 27713',
#  'Kansas City, Missouri 64114',
#  'Minneapolis, Minnesota 55415',
#  'Detroit, Michigan 48202',
#  'Jacksonville, Florida 32224',
#  'Birmingham, Alabama 35294',
#  'Decatur, Georgia 30030-1705',
#  'Durham, North Carolina 27704',
#  'La Mesa, California 91942',
#  'Tampa, Florida 33606',
#  'Peoria, Illinois 61637',
#  'Albertson, New York 11507',
#  'Jacksonville, Florida 32207',
#  'Anaheim, California 92806',
#  'La Jolla, California 92093',
#  'Tucson, Arizona 85721',
#  'Duarte, California 91010',
#  'Eugene, Oregon 97403',
#  'Chicago, Illinois 60007',
#  'Basking Ridge, New Jersey 07920',
#  'Phoenix, Arizona 85012']

# %%
from info import KEY
url = "http://open.mapquestapi.com/geocoding/v1/address?"
results = []

for n in querylist:
    query = f"{url}key={KEY}&location={n}"
    response = requests.get(query)
    json = response.json()
    resultDict = {}
    latitude = json["results"][0]["locations"][0]["latLng"]["lat"]
    longitude = json["results"][0]["locations"][0]["latLng"]["lng"]
    locationzip = mainziplist[querylist.index(n)]
    resultDict = {
        "locationzip":locationzip,
        "longitude":longitude,
        "latitude":latitude
    }
    results.append(resultDict)
results
# Out:
# [{'locationzip': '48073', 'longitude': -83.16537, 'latitude': 42.510516},
#  {'locationzip': '84107', 'longitude': -111.888417, 'latitude': 40.666784},
#  {'locationzip': '55455', 'longitude': -93.265469, 'latitude': 44.9773},
#  {'locationzip': '30322', 'longitude': -84.390185, 'latitude': 33.749099},
#  {'locationzip': '62220', 'longitude': -89.983993, 'latitude': 38.52005},
#  {'locationzip': '10029', 'longitude': -73.986614, 'latitude': 40.730646},
#  {'locationzip': '78705', 'longitude': -97.727404, 'latitude': 30.288272},
#  {'locationzip': '27710', 'longitude': -78.901805, 'latitude': 35.996653},
#  {'locationzip': '85254', 'longitude': -111.899236, 'latitude': 33.509122},
#  {'locationzip': '07601', 'longitude': -74.043474, 'latitude': 40.885933},
#  {'locationzip': '96813', 'longitude': -157.855676, 'latitude': 21.304547},
#  {'locationzip': '94022', 'longitude': -122.419236, 'latitude': 37.779281},
#  {'locationzip': '60452', 'longitude': -87.624421, 'latitude': 41.875555},
#  {'locationzip': '19107', 'longitude': -75.16359, 'latitude': 39.952399},
#  {'locationzip': '60637', 'longitude': -87.624421, 'latitude': 41.875555},
#  {'locationzip': '66160', 'longitude': -94.610453, 'latitude': 39.05565},
#  {'locationzip': '80260', 'longitude': -104.987553, 'latitude': 39.910086},
#  {'locationzip': '98195', 'longitude': -122.330062, 'latitude': 47.603832},
#  {'locationzip': '80045', 'longitude': -104.83192, 'latitude': 39.729432},
#  {'locationzip': '10032', 'longitude': -73.986614, 'latitude': 40.730646},
#  {'locationzip': '10022', 'longitude': -73.966962, 'latitude': 40.760716},
#  {'locationzip': '37232', 'longitude': -86.774353, 'latitude': 36.16223},
#  {'locationzip': '94305', 'longitude': -122.167706, 'latitude': 37.42484},
#  {'locationzip': '19104', 'longitude': -75.16359, 'latitude': 39.952399},
#  {'locationzip': '85258', 'longitude': -111.899236, 'latitude': 33.509122},
#  {'locationzip': '77027', 'longitude': -95.367697, 'latitude': 29.758938},
#  {'locationzip': '20892', 'longitude': -77.094646, 'latitude': 38.984827},
#  {'locationzip': '64111', 'longitude': -94.590162, 'latitude': 39.048908},
#  {'locationzip': '93003', 'longitude': -119.310582, 'latitude': 34.364744},
#  {'locationzip': '02114', 'longitude': -71.058291, 'latitude': 42.360253},
#  {'locationzip': '10016', 'longitude': -73.986614, 'latitude': 40.730646},
#  {'locationzip': '94143', 'longitude': -122.419236, 'latitude': 37.779281},
#  {'locationzip': '63110', 'longitude': -90.257051, 'latitude': 38.622445},
#  {'locationzip': '02114-2621', 'longitude': -71.058291, 'latitude': 42.360253},
#  {'locationzip': '70121', 'longitude': -90.070116, 'latitude': 29.949932},
#  {'locationzip': '37203', 'longitude': -86.774353, 'latitude': 36.16223},
#  {'locationzip': '10467', 'longitude': -73.836696, 'latitude': 40.857033},
#  {'locationzip': '90095', 'longitude': -118.244476, 'latitude': 34.054935},
#  {'locationzip': '27157', 'longitude': -80.269466, 'latitude': 36.089594},
#  {'locationzip': '70112', 'longitude': -90.075941, 'latitude': 29.95635},
#  {'locationzip': '98133', 'longitude': -122.330062, 'latitude': 47.603832},
#  {'locationzip': '45267', 'longitude': -84.51246, 'latitude': 39.101454},
#  {'locationzip': '11501', 'longitude': -73.640684, 'latitude': 40.749268},
#  {'locationzip': '46237', 'longitude': -86.15835, 'latitude': 39.768333},
#  {'locationzip': '33136', 'longitude': -80.193659, 'latitude': 25.774266},
#  {'locationzip': '35222', 'longitude': -86.802433, 'latitude': 33.520682},
#  {'locationzip': '21287', 'longitude': -76.610759, 'latitude': 39.290882},
#  {'locationzip': '06105', 'longitude': -72.690867, 'latitude': 41.764549},
#  {'locationzip': '13326', 'longitude': -74.924321, 'latitude': 42.70063},
#  {'locationzip': '36604', 'longitude': -88.043054, 'latitude': 30.694357},
#  {'locationzip': '23249', 'longitude': -77.43428, 'latitude': 37.538509},
#  {'locationzip': '98104', 'longitude': -100.445882, 'latitude': 39.78373},
#  {'locationzip': '11042', 'longitude': -73.986614, 'latitude': 40.730646},
#  {'locationzip': '94110', 'longitude': -122.419236, 'latitude': 37.779281},
#  {'locationzip': '84108', 'longitude': -111.827485, 'latitude': 40.737347},
#  {'locationzip': '85006', 'longitude': -112.077346, 'latitude': 33.448587},
#  {'locationzip': '33701', 'longitude': -82.631033, 'latitude': 27.778539},
#  {'locationzip': '90048', 'longitude': -118.377419, 'latitude': 34.072022},
#  {'locationzip': '60612', 'longitude': -87.624421, 'latitude': 41.875555},
#  {'locationzip': '77030', 'longitude': -95.367697, 'latitude': 29.758938},
#  {'locationzip': '02115', 'longitude': -71.058291, 'latitude': 42.360253},
#  {'locationzip': '11794', 'longitude': -73.140943, 'latitude': 40.925654},
#  {'locationzip': '35233', 'longitude': -86.802433, 'latitude': 33.520682},
#  {'locationzip': '84132', 'longitude': -111.838608, 'latitude': 40.77121},
#  {'locationzip': '27701', 'longitude': -78.901805, 'latitude': 35.996653},
#  {'locationzip': '60616', 'longitude': -87.624421, 'latitude': 41.875555},
#  {'locationzip': '08901', 'longitude': -74.438394, 'latitude': 40.49363},
#  {'locationzip': '02132', 'longitude': -71.058291, 'latitude': 42.360253},
#  {'locationzip': '27713', 'longitude': -78.901805, 'latitude': 35.996653},
#  {'locationzip': '64114', 'longitude': -94.590322, 'latitude': 38.931189},
#  {'locationzip': '55415', 'longitude': -93.265469, 'latitude': 44.9773},
#  {'locationzip': '48202', 'longitude': -100.445882, 'latitude': 39.78373},
#  {'locationzip': '32224', 'longitude': -81.655651, 'latitude': 30.332184},
#  {'locationzip': '35294', 'longitude': -86.802433, 'latitude': 33.520682},
#  {'locationzip': '30030-1705', 'longitude': -100.445882, 'latitude': 39.78373},
#  {'locationzip': '27704', 'longitude': -100.445882, 'latitude': 39.78373},
#  {'locationzip': '91942', 'longitude': -117.023084, 'latitude': 32.767829},
#  {'locationzip': '33606', 'longitude': -82.458444, 'latitude': 27.94776},
#  {'locationzip': '61637', 'longitude': -89.589101, 'latitude': 40.693861},
#  {'locationzip': '11507', 'longitude': -100.445882, 'latitude': 39.78373},
#  {'locationzip': '32207', 'longitude': -81.655651, 'latitude': 30.332184},
#  {'locationzip': '92806', 'longitude': -117.877454, 'latitude': 33.847751},
#  {'locationzip': '92093', 'longitude': -117.26162, 'latitude': 32.833501},
#  {'locationzip': '85721', 'longitude': -110.926235, 'latitude': 32.221892},
#  {'locationzip': '91010', 'longitude': -117.977287, 'latitude': 34.139451},
#  {'locationzip': '97403', 'longitude': -123.095051, 'latitude': 44.050505},
#  {'locationzip': '60007', 'longitude': -87.624421, 'latitude': 41.875555},
#  {'locationzip': '07920', 'longitude': -74.548569, 'latitude': 40.706794},
#  {'locationzip': '85012', 'longitude': -112.077346, 'latitude': 33.448587}]

# %%
results_df = pd.DataFrame(results)
results_df.head()
# Out:
#   locationzip   longitude   latitude
# 0       48073  -83.165370  42.510516
# 1       84107 -111.888417  40.666784
# 2       55455  -93.265469  44.977300
# 3       30322  -84.390185  33.749099
# 4       62220  -89.983993  38.520050

# %%
engine = db.create_engine('sqlite:///COVID-Clinical-Trials.sqlite')

metadata = db.MetaData()

results_df.to_sql("lat_long", con=engine, if_exists="replace")

# %%
connection = engine.connect()
query = connection.execute("SELECT DISTINCT c.nctid, c.brieftitle, c.facility, c.overallstatus, c.contactname, c.contactphone, c.contactemail, c.enrollmentcount, c.locationstate, l.latitude, l.longitude, p.phase FROM COVID_ClinicalTrials as c INNER JOIN lat_long as l on c.locationzip = l.locationzip INNER JOIN Phase_Recordings as p on c.nctid = p.nctid")

# %%
query

# %%
d, results = {}, []
for rowproxy in query:
    # rowproxy.items() returns an array like [(key0, value0), (key1, value1)] > thank you stackoverflow!
    for column, value in rowproxy.items():
        # build up the dictionary
        d = {**d, **{column: value}}
    results.append(d)
connection.close()
results
# Out:
# [{'nctid': 'NCT04329832',
#   'brieftitle': 'Hydroxychloroquine vs. Azithromycin for Hospitalized Patients With Suspected or Confirmed COVID-19',
#   'facility': 'Intermountain Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Valerie T Aston, MBA',
#   'contactphone': '8015074606',
#   'contactemail': 'Valerie.Aston@imail.org',
#   'enrollmentcount': '300',
#   'locationstate': 'Utah',
#   'latitude': 40.666784,
#   'longitude': -111.888417,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04334382',
#   'brieftitle': 'Hydroxychloroquine vs. Azithromycin for Outpatients in Utah With COVID-19',
#   'facility': 'Intermountain Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Valerie T Aston, MBA',
#   'contactphone': '8015074606',
#   'contactemail': 'Valerie.Aston@imail.org',
#   'enrollmentcount': '1550',
#   'locationstate': 'Utah',
#   'latitude': 40.666784,
#   'longitude': -111.888417,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04331366',
#   'brieftitle': 'Bidirectional Oxygenation Valve in the Management of Pulmonary Complications of COVID-19',
#   'facility': 'Emory University Hospital',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Jeffrey Miller, MD',
#   'contactphone': '404-778-7200',
#   'contactemail': 'jeffrey.miller@emory.edu',
#   'enrollmentcount': '5',
#   'locationstate': 'Georgia',
#   'latitude': 33.749099,
#   'longitude': -84.390185,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04342663',
#   'brieftitle': 'A Double-blind, Placebo-controlled Clinical Trial of Fluvoxamine for Symptomatic Individuals With COVID-19 Infection',
#   'facility': 'BJC',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Angela Stevens',
#   'contactphone': '(314)362-6291',
#   'contactemail': 'stevens.a@wustl.edu',
#   'enrollmentcount': '152',
#   'locationstate': 'Illinois',
#   'latitude': 38.52005,
#   'longitude': -89.983993,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04351243',
#   'brieftitle': 'A Study to Assess the Efficacy and Safety of of Gimsilumab in Subjects With Lung Injury or Acute Respiratory Distress Syndrome Secondary to COVID-19.',
#   'facility': 'Mount Sinai',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Arnaud Bastien, MD',
#   'contactphone': '(609)-410-2691',
#   'contactemail': 'arnaud.bastien@roivant.com',
#   'enrollmentcount': '270',
#   'locationstate': 'New York',
#   'latitude': 40.730646,
#   'longitude': -73.986614,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04350073',
#   'brieftitle': 'Longitudinal Energy Expenditure and Metabolic Effects in Patients With COVID-19 (LEEP-COVID)',
#   'facility': 'Duke University Medial Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Paul E Wischmeyer, MD, EDIC, FASPEN, FCCM',
#   'contactphone': '919-681-6437',
#   'contactemail': 'paul.wischmeyer@duke.edu',
#   'enrollmentcount': '120',
#   'locationstate': 'North Carolina',
#   'latitude': 35.996653,
#   'longitude': -78.901805,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04344457',
#   'brieftitle': 'Evaluate the Efficacy and Safety of Oral Hydroxychloroquine, Indomethacin and Zithromax in Subjects With Mild Symptoms of COVID-19',
#   'facility': 'Perseverance Research Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Nicole C Hank, PhD,MCR,MHSM',
#   'contactphone': '4804716132',
#   'contactemail': 'nhank@prcresearcheducation.com',
#   'enrollmentcount': '80',
#   'locationstate': 'Arizona',
#   'latitude': 33.509122,
#   'longitude': -111.899236,
#   'phase': 'Phase 1'},
#  {'nctid': 'NCT04344457',
#   'brieftitle': 'Evaluate the Efficacy and Safety of Oral Hydroxychloroquine, Indomethacin and Zithromax in Subjects With Mild Symptoms of COVID-19',
#   'facility': 'Perseverance Research Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Nicole C Hank, PhD,MCR,MHSM',
#   'contactphone': '4804716132',
#   'contactemail': 'nhank@prcresearcheducation.com',
#   'enrollmentcount': '80',
#   'locationstate': 'Arizona',
#   'latitude': 33.509122,
#   'longitude': -111.899236,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04343755',
#   'brieftitle': 'Convalescent Plasma as Treatment for Hospitalized Subjects With COVID-19 Infection',
#   'facility': 'Hackensack University Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Mariefel Vendivil',
#   'contactphone': '551-996-5828',
#   'contactemail': 'Mariefel.Vendivil@HackensackMeridian.org',
#   'enrollmentcount': '55',
#   'locationstate': 'New Jersey',
#   'latitude': 40.885933,
#   'longitude': -74.043474,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04345692',
#   'brieftitle': 'A Randomized Controlled Clinical Trial: Hydroxychloroquine for the Treatment of COVID-19 in Hospitalized Patients',
#   'facility': "Queen's Medical Center",
#   'overallstatus': 'Recruiting',
#   'contactname': 'Todd Seto, MD',
#   'contactphone': '808 354-3533',
#   'contactemail': 'tseto@queens.org',
#   'enrollmentcount': '350',
#   'locationstate': 'Hawaii',
#   'latitude': 21.304547,
#   'longitude': -157.855676,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04344015',
#   'brieftitle': 'COVID-19 Plasma Collection',
#   'facility': 'Thomas Jefferson University Hospital',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Julie Karp, MD',
#   'contactphone': '215-503-4838',
#   'contactemail': 'CovidPlasma@jefferson.edu',
#   'enrollmentcount': '2000',
#   'locationstate': 'Pennsylvania',
#   'latitude': 39.952399,
#   'longitude': -75.16359,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04343690',
#   'brieftitle': 'COPING With COVID-19( CWC-19)',
#   'facility': 'Duke University',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Erika Ratcliffe',
#   'contactphone': '919-681-5006',
#   'contactemail': 'erika.ratcliffe@duke.edu',
#   'enrollmentcount': '100',
#   'locationstate': 'North Carolina',
#   'latitude': 35.996653,
#   'longitude': -78.901805,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04340050',
#   'brieftitle': 'COVID-19 Convalescent Plasma',
#   'facility': 'University of Chicago Medicine',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Maria Lucia Madariaga, MD',
#   'contactphone': '773-270-2004',
#   'contactemail': 'mlmadariaga@bsd.uchicago.edu',
#   'enrollmentcount': '10',
#   'locationstate': 'Illinois',
#   'latitude': 41.875555,
#   'longitude': -87.624421,
#   'phase': 'Early Phase 1'},
#  {'nctid': 'NCT04335123',
#   'brieftitle': 'Study of Open Label Losartan in COVID-19',
#   'facility': 'University of Kansas Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Matthias Salathe, MD',
#   'contactphone': '9135886000',
#   'contactemail': 'msalathe@kumc.edu',
#   'enrollmentcount': '50',
#   'locationstate': 'Kansas',
#   'latitude': 39.05565,
#   'longitude': -94.610453,
#   'phase': 'Phase 1'},
#  {'nctid': 'NCT04348864',
#   'brieftitle': 'COVID-19 Antibody Self-testing Using Virtual Point-of-care',
#   'facility': 'Neuroganics',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Donald Cooper, Ph.D.',
#   'contactphone': '7204313495',
#   'contactemail': 'COVID19study@protonmail.com',
#   'enrollmentcount': '100',
#   'locationstate': 'Colorado',
#   'latitude': 39.910086,
#   'longitude': -104.987553,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04340232',
#   'brieftitle': 'Safety and Efficacy of Baricitinib for COVID-19',
#   'facility': 'University of Colorado, Denver',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Angela Rachubinski, PhD',
#   'contactphone': '(720) 507-9107',
#   'contactemail': 'bari-covid19@cuanschutz.edu',
#   'enrollmentcount': '80',
#   'locationstate': 'Colorado',
#   'latitude': 39.729432,
#   'longitude': -104.83192,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04340232',
#   'brieftitle': 'Safety and Efficacy of Baricitinib for COVID-19',
#   'facility': 'University of Colorado, Denver',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Angela Rachubinski, PhD',
#   'contactphone': '(720) 507-9107',
#   'contactemail': 'bari-covid19@cuanschutz.edu',
#   'enrollmentcount': '80',
#   'locationstate': 'Colorado',
#   'latitude': 39.729432,
#   'longitude': -104.83192,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04318444',
#   'brieftitle': 'Hydroxychloroquine Post Exposure Prophylaxis for Coronavirus Disease (COVID-19)',
#   'facility': 'Columbia University Irving Medical Center',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Elizabeth Oelsner, MD, MPH',
#   'contactphone': '212-305-9056',
#   'contactemail': 'eco7@cumc.columbia.edu',
#   'enrollmentcount': '1600',
#   'locationstate': 'New York',
#   'latitude': 40.730646,
#   'longitude': -73.986614,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04318444',
#   'brieftitle': 'Hydroxychloroquine Post Exposure Prophylaxis for Coronavirus Disease (COVID-19)',
#   'facility': 'Columbia University Irving Medical Center',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Elizabeth Oelsner, MD, MPH',
#   'contactphone': '212-305-9056',
#   'contactemail': 'eco7@cumc.columbia.edu',
#   'enrollmentcount': '1600',
#   'locationstate': 'New York',
#   'latitude': 40.730646,
#   'longitude': -73.986614,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04352946',
#   'brieftitle': 'HEalth Care Worker pROphylaxis Against COVID-19: The HERO Trial',
#   'facility': 'The New York Center for Travel and Tropical Medicine',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Bradley A Connor, MD',
#   'contactphone': '9172138998',
#   'contactemail': 'bconnor1@gmail.com',
#   'enrollmentcount': '374',
#   'locationstate': 'New York',
#   'latitude': 40.760716,
#   'longitude': -73.966962,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04331795',
#   'brieftitle': 'Tocilizumab to Prevent Clinical Decompensation in Hospitalized, Non-critically Ill Patients With COVID-19 Pneumonitis',
#   'facility': 'University of Chicago Medicine',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Pankti Reid, MD, MPH',
#   'contactphone': '7737021220',
#   'contactemail': 'pankti.reid@uchospitals.edu',
#   'enrollmentcount': '50',
#   'locationstate': 'Illinois',
#   'latitude': 41.875555,
#   'longitude': -87.624421,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04359810',
#   'brieftitle': 'Plasma Therapy of COVID-19 in Critically Ill Patients',
#   'facility': 'Columbia University Irving Medical Center/NYP',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': "Max O'Donnell, MD",
#   'contactphone': '212-305-5794',
#   'contactemail': 'mo2130@cumc.columbia.edu',
#   'enrollmentcount': '105',
#   'locationstate': 'New York',
#   'latitude': 40.730646,
#   'longitude': -73.986614,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04347954',
#   'brieftitle': 'PVP-I Nasal Sprays and SARS-CoV-2 Nasopharyngeal Titers (for COVID-19)',
#   'facility': 'Stanford Health Care',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Peter H Hwang, MD',
#   'contactphone': '650-725-6500',
#   'contactemail': 'hwangph@stanford.edu',
#   'enrollmentcount': '45',
#   'locationstate': 'California',
#   'latitude': 37.42484,
#   'longitude': -122.167706,
#   'phase': 'Phase 1'},
#  {'nctid': 'NCT04347954',
#   'brieftitle': 'PVP-I Nasal Sprays and SARS-CoV-2 Nasopharyngeal Titers (for COVID-19)',
#   'facility': 'Stanford Health Care',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Peter H Hwang, MD',
#   'contactphone': '650-725-6500',
#   'contactemail': 'hwangph@stanford.edu',
#   'enrollmentcount': '45',
#   'locationstate': 'California',
#   'latitude': 37.42484,
#   'longitude': -122.167706,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04329923',
#   'brieftitle': 'The PATCH Trial (Prevention And Treatment of COVID-19 With Hydroxychloroquine)',
#   'facility': 'University of Pennsylvania',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Amelia Anderson',
#   'contactphone': '215-509-5690',
#   'contactemail': 'amelia.anderson@pennmedicine.upenn.edu',
#   'enrollmentcount': '400',
#   'locationstate': 'Pennsylvania',
#   'latitude': 39.952399,
#   'longitude': -75.16359,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04339426',
#   'brieftitle': 'Atovaquone and Azithromycin Combination for Confirmed COVID-19 Infection',
#   'facility': 'HonorHealth',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Karen Lewandowski, RN',
#   'contactphone': '480-583-0760',
#   'contactemail': 'klewandowski@honorhealth.com',
#   'enrollmentcount': '25',
#   'locationstate': 'Arizona',
#   'latitude': 33.509122,
#   'longitude': -111.899236,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04350476',
#   'brieftitle': 'COVID-19 Remote Monitoring',
#   'facility': 'Icahn School of Medicine at Mount Sinai',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Sam Cammack',
#   'contactphone': '212-824-8931',
#   'contactemail': 'sam.cammack@mountsinai.org',
#   'enrollmentcount': '1000',
#   'locationstate': 'New York',
#   'latitude': 40.730646,
#   'longitude': -73.986614,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04361214',
#   'brieftitle': 'Leflunomide in Mild COVID-19 Patients',
#   'facility': 'University of Chicago',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Michael Millis, MD',
#   'contactphone': '773 702 6319',
#   'contactemail': 'mmillis@surgery.bsd.uchicago.edu',
#   'enrollmentcount': '20',
#   'locationstate': 'Illinois',
#   'latitude': 41.875555,
#   'longitude': -87.624421,
#   'phase': 'Phase 1'},
#  {'nctid': 'NCT04362189',
#   'brieftitle': 'Efficacy and Safety Study of Allogeneic HB-adMSCs for the Treatment of COVID-19',
#   'facility': 'River Oaks Hospital and Clinics',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Katherine Ruppert, PhD',
#   'contactphone': '8329758840',
#   'contactemail': 'katie@hopebio.org',
#   'enrollmentcount': '110',
#   'locationstate': 'Texas',
#   'latitude': 29.758938,
#   'longitude': -95.367697,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04351620',
#   'brieftitle': 'High-dose Hydroxychloroquine for the Treatment of Ambulatory Patients With Mild COVID-19',
#   'facility': 'University of Chicago',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Reem Jan, MBBS BSc',
#   'contactphone': '734-972-7953',
#   'contactemail': 'rjan@medicine.bsd.uchicago.edu',
#   'enrollmentcount': '20',
#   'locationstate': 'Illinois',
#   'latitude': 41.875555,
#   'longitude': -87.624421,
#   'phase': 'Phase 1'},
#  {'nctid': 'NCT04350593',
#   'brieftitle': 'Dapagliflozin in Respiratory Failure in Patients With COVID-19',
#   'facility': "Saint Luke's Mid America Heart Institute",
#   'overallstatus': 'Recruiting',
#   'contactname': 'Sheryl Windsor',
#   'contactphone': '816-932-9858',
#   'contactemail': 'swindsor@saint-lukes.org',
#   'enrollmentcount': '900',
#   'locationstate': 'Missouri',
#   'latitude': 39.048908,
#   'longitude': -94.590162,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04334512',
#   'brieftitle': 'A Study of Quintuple Therapy to Treat COVID-19 Infection',
#   'facility': 'ProgenaBiome',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Sabine Hazan, MD',
#   'contactphone': '805-200-7436',
#   'contactemail': 'sabinehazan@aim.com',
#   'enrollmentcount': '600',
#   'locationstate': 'California',
#   'latitude': 34.364744,
#   'longitude': -119.310582,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04356937',
#   'brieftitle': 'Efficacy of Tocilizumab on Patients With COVID-19',
#   'facility': 'Massachusetts General Hospital',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'John H Stone, MD,MPH',
#   'contactphone': '6177267938',
#   'contactemail': 'JHSTONE@mgh.harvard.edu',
#   'enrollmentcount': '300',
#   'locationstate': 'Massachusetts',
#   'latitude': 42.360253,
#   'longitude': -71.058291,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04335084',
#   'brieftitle': 'A Study of Hydroxychloroquine, Vitamin C, Vitamin D, and Zinc for the Prevention of COVID-19 Infection',
#   'facility': 'ProgenaBiome',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Sabine Hazan, MD',
#   'contactphone': '805-339-0549',
#   'contactemail': 'drsabinehazan@progenabiome.com',
#   'enrollmentcount': '600',
#   'locationstate': 'California',
#   'latitude': 34.364744,
#   'longitude': -119.310582,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04360551',
#   'brieftitle': 'Pilot Clinical Trial of the Safety and Efficacy of Telmisartan for the Mitigation of Pulmonary and Cardiac Complications in COVID-19 Patients',
#   'facility': 'University of Hawaii - Manoa, John A Burns School of Medicine UH Clinics at Kakaako',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Cecilia M Shikuma, MD',
#   'contactphone': '808 692-1328',
#   'contactemail': 'shikuma@hawaii.edu',
#   'enrollmentcount': '40',
#   'locationstate': 'Hawaii',
#   'latitude': 21.304547,
#   'longitude': -157.855676,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04354870',
#   'brieftitle': 'COVID-19 PrEP HCW HCQ Study',
#   'facility': 'NYU Langone Health',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Emily Beato',
#   'contactphone': '+1 212 263 6411',
#   'contactemail': 'emily.beato@nyulangone.org',
#   'enrollmentcount': '350',
#   'locationstate': 'New York',
#   'latitude': 40.730646,
#   'longitude': -73.986614,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04354714',
#   'brieftitle': 'Ruxolitinib to Combat COVID-19',
#   'facility': 'Washington University School of Medicine',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'John DiPersio, M.D., Ph.D.',
#   'contactphone': '314-454-8491',
#   'contactemail': 'jdipersi@wustl.edu',
#   'enrollmentcount': '25',
#   'locationstate': 'Missouri',
#   'latitude': 38.622445,
#   'longitude': -90.257051,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04305457',
#   'brieftitle': 'Nitric Oxide Gas Inhalation Therapy for Mild/Moderate COVID-19',
#   'facility': 'Massachusetts General Hospital',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Lorenzo Berra',
#   'contactphone': '+16176437733',
#   'contactemail': 'lberra@mgh.harvard.edu',
#   'enrollmentcount': '240',
#   'locationstate': 'Massachusetts',
#   'latitude': 42.360253,
#   'longitude': -71.058291,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04347538',
#   'brieftitle': 'Impact of Nasal Saline Irrigations on Viral Load in Patients With COVID-19',
#   'facility': 'Vanderblt University Medical Center',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Kate Von Wahlde, MJ, CCRP',
#   'contactphone': '615-322-0333',
#   'contactemail': 'kate.vonwahlde@vumc.org',
#   'enrollmentcount': '90',
#   'locationstate': 'Tennessee',
#   'latitude': 36.16223,
#   'longitude': -86.774353,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04359277',
#   'brieftitle': 'A Randomized Trial of Anticoagulation Strategies in COVID-19',
#   'facility': 'NYU Langone Health',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Jeffrey Berger, MD',
#   'contactphone': '212-263-4004',
#   'contactemail': 'jeffrey.berger@nyumc.org',
#   'enrollmentcount': '1000',
#   'locationstate': 'New York',
#   'latitude': 40.730646,
#   'longitude': -73.986614,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04343183',
#   'brieftitle': 'Hyperbaric Oxygen Therapy (HBOT) as a Treatment for COVID-19 (COVID-19) Infection',
#   'facility': 'Ochsner Medical Center',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'John F Engle, MD',
#   'contactphone': '985-768-8918',
#   'contactemail': 'englemd94@gmail.com',
#   'enrollmentcount': '48',
#   'locationstate': 'Louisiana',
#   'latitude': 29.949932,
#   'longitude': -90.070116,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04359797',
#   'brieftitle': 'COVID-19 Patient Positioning Pragmatic Trial',
#   'facility': 'Vanderbilt University Medical Center',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Todd W Rice, MD, MSc',
#   'contactphone': '615-322-3412',
#   'contactemail': 'todd.rice@vumc.org',
#   'enrollmentcount': '300',
#   'locationstate': 'Tennessee',
#   'latitude': 36.16223,
#   'longitude': -86.774353,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04362176',
#   'brieftitle': 'Passive Immunity Trial of Nashville II',
#   'facility': 'Vanderbilt University Medical Center',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Amanda J Bistran-Hall',
#   'contactphone': '(615) 875-8531',
#   'contactemail': 'amanda.j.bistran-hall@vumc.org',
#   'enrollmentcount': '500',
#   'locationstate': 'Tennessee',
#   'latitude': 36.16223,
#   'longitude': -86.774353,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04332107',
#   'brieftitle': 'Azithromycin for COVID-19 Treatment in Outpatients Nationwide',
#   'facility': 'University of California San Francisco',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Jessica M Brogdon, MPH',
#   'contactphone': '(415) 514-1582',
#   'contactemail': 'ACTIONTrial@ucsf.edu',
#   'enrollmentcount': '2271',
#   'locationstate': 'California',
#   'latitude': 37.779281,
#   'longitude': -122.419236,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04343976',
#   'brieftitle': 'Pegylated Interferon Lambda Treatment for COVID-19',
#   'facility': 'Massachusetts General Hospital',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Jenna Gustafson, MSc',
#   'contactphone': '6177243836',
#   'contactemail': 'JLGustafson@mgh.harvard.edu',
#   'enrollmentcount': '20',
#   'locationstate': 'Massachusetts',
#   'latitude': 42.360253,
#   'longitude': -71.058291,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04347239',
#   'brieftitle': 'Study to Evaluate the Efficacy and Safety of Leronlimab for Patients With Severe or Critical Coronavirus Disease 2019 (COVID-19)',
#   'facility': 'Montefiore Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Kush Dhody, MBBS, MS, CCRA',
#   'contactphone': '301-956-2536',
#   'contactemail': 'kushd@amarexcro.com',
#   'enrollmentcount': '390',
#   'locationstate': 'New York',
#   'latitude': 40.857033,
#   'longitude': -73.836696,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04344236',
#   'brieftitle': 'Gargling and Nasal Rinses to Reduce Oro- and Nasopharyngeal Viral Load in Patients With COVID-19',
#   'facility': 'NYU Langone Health',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Scott Rickert, MD',
#   'contactphone': '646-501-7890',
#   'contactemail': 'scott.rickert@nyulangone.org',
#   'enrollmentcount': '48',
#   'locationstate': 'New York',
#   'latitude': 40.730646,
#   'longitude': -73.986614,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04319445',
#   'brieftitle': 'Mindfulness During COVID-19',
#   'facility': 'Wake Forest Health Sciences',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Rebecca E Wells, MD, MPH',
#   'contactphone': '336-716-2357',
#   'contactemail': 'WFBH_Mindfulness@wakehealth.edu',
#   'enrollmentcount': '200',
#   'locationstate': 'North Carolina',
#   'latitude': 36.089594,
#   'longitude': -80.269466,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04344444',
#   'brieftitle': 'Treatment in Patients With Suspected or Confirmed COVID-19 With Early Moderate or Severe Disease',
#   'facility': 'University Medical Center New Orleans',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Jeannine Ascani, MS',
#   'contactphone': '5047023141',
#   'contactemail': 'jeannine.ascani@lcmchealth.org',
#   'enrollmentcount': '600',
#   'locationstate': 'Louisiana',
#   'latitude': 29.95635,
#   'longitude': -90.075941,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04341675',
#   'brieftitle': 'Sirolimus Treatment in Hospitalized Patients With COVID-19 Pneumonia',
#   'facility': 'University of Cincinnati',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Nishant Gupta, MD',
#   'contactphone': '5135584831',
#   'contactemail': 'guptans@ucmail.uc.edu',
#   'enrollmentcount': '30',
#   'locationstate': 'Ohio',
#   'latitude': 39.101454,
#   'longitude': -84.51246,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04338828',
#   'brieftitle': 'Nitric Oxide Inhalation Therapy for COVID-19 Infections in the ED',
#   'facility': 'Massachusetts General Hospital',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'N. Stuart Harris, MD, MFA',
#   'contactphone': '617-724-3290',
#   'contactemail': 'nsharris@mgh.harvard.edu',
#   'enrollmentcount': '260',
#   'locationstate': 'Massachusetts',
#   'latitude': 42.360253,
#   'longitude': -71.058291,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04332081',
#   'brieftitle': 'Hyperbaric Oxygen for COVID-19 Patients',
#   'facility': 'NYU Winthrop Hospital',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Scott Gorenstein',
#   'contactphone': '516-663-8498',
#   'contactemail': 'Scott.Gorenstein@nyulangone.org',
#   'enrollmentcount': '40',
#   'locationstate': 'New York',
#   'latitude': 40.749268,
#   'longitude': -73.640684,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04342897',
#   'brieftitle': 'A Study of LY3127804 in Participants With COVID-19',
#   'facility': 'Franciscan St. Francis Health',
#   'overallstatus': 'Recruiting',
#   'contactname': 'There may be multiple sites in this clinical trial. 1-877-CTLILLY (1-877-285-4559) or',
#   'contactphone': '1-317-615-4559',
#   'contactemail': 'ClinicalTrials.gov@lilly.com',
#   'enrollmentcount': '200',
#   'locationstate': 'Indiana',
#   'latitude': 39.768333,
#   'longitude': -86.15835,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04355728',
#   'brieftitle': 'Use of UC-MSCs for COVID-19 Patients',
#   'facility': 'Diabetes Research Institute, University of Miami Miller School of Medicine',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Camillo Ricordi, MD',
#   'contactphone': '305-243-6913',
#   'contactemail': 'cricordi@miami.edu',
#   'enrollmentcount': '24',
#   'locationstate': 'Florida',
#   'latitude': 25.774266,
#   'longitude': -80.193659,
#   'phase': 'Phase 1'},
#  {'nctid': 'NCT04355728',
#   'brieftitle': 'Use of UC-MSCs for COVID-19 Patients',
#   'facility': 'Diabetes Research Institute, University of Miami Miller School of Medicine',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Camillo Ricordi, MD',
#   'contactphone': '305-243-6913',
#   'contactemail': 'cricordi@miami.edu',
#   'enrollmentcount': '24',
#   'locationstate': 'Florida',
#   'latitude': 25.774266,
#   'longitude': -80.193659,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04338074',
#   'brieftitle': 'TXA and Corona Virus 2019 (COVID19) in Outpatients',
#   'facility': 'University of Alabama at Birmingham',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Timothy J Ness, MD PhD',
#   'contactphone': '2059079743',
#   'contactemail': 'tness@uabmc.edu',
#   'enrollmentcount': '100',
#   'locationstate': 'Alabama',
#   'latitude': 33.520682,
#   'longitude': -86.802433,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04343989',
#   'brieftitle': 'A Randomized Placebo-controlled Safety and Dose-finding Study for the Use of the IL-6 Inhibitor Clazakizumab in Patients With Life-threatening COVID-19 Infection',
#   'facility': 'New York University School of Medicine',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Bonnie Lonze, MD',
#   'contactphone': '212-263-8365',
#   'contactemail': 'bonnie.lonze@nyulangone.org',
#   'enrollmentcount': '90',
#   'locationstate': 'New York',
#   'latitude': 40.730646,
#   'longitude': -73.986614,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04328467',
#   'brieftitle': 'Pre-exposure Prophylaxis for SARS-Coronavirus-2',
#   'facility': 'Nationwide Enrollment via Internet, please email: covid19@umn.edu',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Radha Rajasingham (Please Email), MD',
#   'contactphone': '612-626-8171',
#   'contactemail': 'covid19prep@umn.edu',
#   'enrollmentcount': '3500',
#   'locationstate': 'Minnesota',
#   'latitude': 44.9773,
#   'longitude': -93.265469,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04347226',
#   'brieftitle': 'Anti-Interleukin-8 (Anti-IL-8) for Cancer Patients With COVID-19',
#   'facility': 'Columbia University Irving Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Lisa Olmos, RN',
#   'contactphone': '212.342.5162',
#   'contactemail': 'cancerclinicaltrials@cumc.columbia.edu',
#   'enrollmentcount': '138',
#   'locationstate': 'New York',
#   'latitude': 40.730646,
#   'longitude': -73.986614,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04344600',
#   'brieftitle': 'Peginterferon Lambda-1a for the Prevention and Treatment of SARS-CoV-2 Infection',
#   'facility': 'Johns Hopkins Hospital',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Stephanie Katz, BSN',
#   'contactphone': '443-997-1900',
#   'contactemail': 'ssneddo2@jhmi.edu',
#   'enrollmentcount': '164',
#   'locationstate': 'Maryland',
#   'latitude': 39.290882,
#   'longitude': -76.610759,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04343261',
#   'brieftitle': 'Convalescent Plasma in the Treatment of COVID 19',
#   'facility': 'Trinity Health Of New England',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Latha Dulipsingh, MD',
#   'contactphone': '860-714-4402',
#   'contactemail': 'Latha.Dulipsingh@trinityhealthofne.org',
#   'enrollmentcount': '15',
#   'locationstate': 'Connecticut',
#   'latitude': 41.764549,
#   'longitude': -72.690867,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04328012',
#   'brieftitle': 'COVID MED Trial - Comparison Of Therapeutics for Hospitalized Patients Infected With SARS-CoV-2',
#   'facility': 'Bassett Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Jennifer Victory, RN',
#   'contactphone': '6075476965',
#   'contactemail': 'jennifer.victory@bassett.org',
#   'enrollmentcount': '4000',
#   'locationstate': 'New York',
#   'latitude': 42.70063,
#   'longitude': -74.924321,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04328012',
#   'brieftitle': 'COVID MED Trial - Comparison Of Therapeutics for Hospitalized Patients Infected With SARS-CoV-2',
#   'facility': 'Bassett Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Jennifer Victory, RN',
#   'contactphone': '6075476965',
#   'contactemail': 'jennifer.victory@bassett.org',
#   'enrollmentcount': '4000',
#   'locationstate': 'New York',
#   'latitude': 42.70063,
#   'longitude': -74.924321,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04353271',
#   'brieftitle': 'Trial of Hydroxychloroquine In Covid-19 Kinetics',
#   'facility': 'University of South Alabama',
#   'overallstatus': 'Recruiting',
#   'contactname': 'William O Richards, MD',
#   'contactphone': '2514717993',
#   'contactemail': 'brichards@health.southalabama.edu',
#   'enrollmentcount': '58',
#   'locationstate': 'Alabama',
#   'latitude': 30.694357,
#   'longitude': -88.043054,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04353271',
#   'brieftitle': 'Trial of Hydroxychloroquine In Covid-19 Kinetics',
#   'facility': 'University of South Alabama',
#   'overallstatus': 'Recruiting',
#   'contactname': 'William O Richards, MD',
#   'contactphone': '2514717993',
#   'contactemail': 'brichards@health.southalabama.edu',
#   'enrollmentcount': '58',
#   'locationstate': 'Alabama',
#   'latitude': 30.694357,
#   'longitude': -88.043054,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04344184',
#   'brieftitle': 'Early Infusion of Vitamin C for Treatment of Novel COVID-19 Acute Lung Injury (EVICT-CORONA-ALI)',
#   'facility': 'Hunter Holmes McGuire VA Medical Center',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Markos G Kashiouris, MD MPH',
#   'contactphone': '804-305-7187',
#   'contactemail': 'mkashiouris@vcu.edu',
#   'enrollmentcount': '200',
#   'locationstate': 'Virginia',
#   'latitude': 37.538509,
#   'longitude': -77.43428,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04343651',
#   'brieftitle': 'Study to Evaluate the Efficacy and Safety of Leronlimab for Mild to Moderate COVID-19',
#   'facility': 'Montefiore Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Kush Dhody, MBBS, MS, CCRA',
#   'contactphone': '301-956-2536',
#   'contactemail': 'kushd@amarexcro.com',
#   'enrollmentcount': '75',
#   'locationstate': 'New York',
#   'latitude': 40.857033,
#   'longitude': -73.836696,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04354428',
#   'brieftitle': 'Treatment for SARS-CoV-2 in High-Risk Adult Outpatients',
#   'facility': 'University of Washington Coordinating Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Christine Johnston, MD, MPH',
#   'contactphone': '206-520-4340',
#   'contactemail': 'cjohnsto@uw.edu',
#   'enrollmentcount': '630',
#   'locationstate': 'Washington',
#   'latitude': 39.78373,
#   'longitude': -100.445882,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04354428',
#   'brieftitle': 'Treatment for SARS-CoV-2 in High-Risk Adult Outpatients',
#   'facility': 'University of Washington Coordinating Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Christine Johnston, MD, MPH',
#   'contactphone': '206-520-4340',
#   'contactemail': 'cjohnsto@uw.edu',
#   'enrollmentcount': '630',
#   'locationstate': 'Washington',
#   'latitude': 39.78373,
#   'longitude': -100.445882,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04353037',
#   'brieftitle': 'PATCH 2&3:Prevention & Treatment of COVID-19 (Severe Acute Respiratory Syndrome Coronavirus 2) With Hydroxychloroquine',
#   'facility': 'ProHealth New York',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Daniel Griffin, MD, PhD',
#   'contactphone': '516-656-6500',
#   'contactemail': 'phs@prohealth-care.com',
#   'enrollmentcount': '850',
#   'locationstate': 'New York',
#   'latitude': 40.730646,
#   'longitude': -73.986614,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04342169',
#   'brieftitle': 'University of Utah COVID-19 Hydrochloroquine Trial',
#   'facility': 'University of Utah',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Christina Pacchia, PhD',
#   'contactphone': '8012138735',
#   'contactemail': 'christina.pacchia@hsc.utah.edu',
#   'enrollmentcount': '400',
#   'locationstate': 'Utah',
#   'latitude': 40.737347,
#   'longitude': -111.827485,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04336774',
#   'brieftitle': 'CAPTION AI to Minimize Risk of COVID Exposure',
#   'facility': 'Duke University Medical Center',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Kristine Arges, BSN',
#   'contactphone': '919-668-0927',
#   'contactemail': 'kristine.arges@duke.edu',
#   'enrollmentcount': '500',
#   'locationstate': 'North Carolina',
#   'latitude': 35.996653,
#   'longitude': -78.901805,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04329533',
#   'brieftitle': 'Effects of Using Mobile App on Perceived Stress During COVID-19 Pandemic',
#   'facility': "Banner University Medicine Women's Institute",
#   'overallstatus': 'Recruiting',
#   'contactname': 'Rachael Smith, DO',
#   'contactphone': '1-541-601-9106',
#   'contactemail': 'rachael.smith@bannerhealth.com',
#   'enrollmentcount': '150',
#   'locationstate': 'Arizona',
#   'latitude': 33.448587,
#   'longitude': -112.077346,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04354155',
#   'brieftitle': 'COVID-19 Anticoagulation in Children - Thromboprophlaxis (COVAC-TP) Trial',
#   'facility': "Johns Hopkins All Children's Hospital",
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Frances L Hamblin, MSHS',
#   'contactphone': '7277672460',
#   'contactemail': 'Frances.Hamblin@jhmi.edu',
#   'enrollmentcount': '38',
#   'locationstate': 'Florida',
#   'latitude': 27.778539,
#   'longitude': -82.631033,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04353206',
#   'brieftitle': 'Convalescent Plasma in ICU Patients With COVID-19-induced Respiratory Failure',
#   'facility': '8700 Beverly Blvd.',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Noah Merin, MD PhD',
#   'contactphone': '310-423-1160',
#   'contactemail': 'Noah.Merin@cshs.org',
#   'enrollmentcount': '90',
#   'locationstate': 'California',
#   'latitude': 34.072022,
#   'longitude': -118.377419,
#   'phase': 'Early Phase 1'},
#  {'nctid': 'NCT04325906',
#   'brieftitle': 'Early PP With HFNC Versus HFNC in COVID-19 Induced Moderate to Severe ARDS',
#   'facility': 'Rush University Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Jie Li, PhD',
#   'contactphone': '312-947-0065',
#   'contactemail': 'Jie_Li@rush.edu',
#   'enrollmentcount': '346',
#   'locationstate': 'Illinois',
#   'latitude': 41.875555,
#   'longitude': -87.624421,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04345601',
#   'brieftitle': 'Mesenchymal Stromal Cells for the Treatment of SARS-CoV-2 Induced Acute Respiratory Failure (COVID-19 Disease)',
#   'facility': 'Houston Methodist Hospital',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'LaQuisa Hill, MD',
#   'contactphone': '(713) 441-1450',
#   'contactemail': 'LaQuisa.Hill@bcm.edu',
#   'enrollmentcount': '30',
#   'locationstate': 'Texas',
#   'latitude': 29.758938,
#   'longitude': -95.367697,
#   'phase': 'Early Phase 1'},
#  {'nctid': 'NCT04341935',
#   'brieftitle': 'Effects of DPP4 Inhibition on COVID-19',
#   'facility': 'University of Miami',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Gianluca Iacobellis, MD PhD',
#   'contactphone': '3052433636',
#   'contactemail': 'giacobellis@med.miami.edu',
#   'enrollmentcount': '20',
#   'locationstate': 'Florida',
#   'latitude': 25.774266,
#   'longitude': -80.193659,
#   'phase': 'Phase 4'},
#  {'nctid': 'NCT04359329',
#   'brieftitle': 'Estrogen Patch for COVID-19 Symptoms',
#   'facility': 'Stony Brook University Hospital',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Christina Preece',
#   'contactphone': '631-371-3309',
#   'contactemail': 'PatchStudy@stonybrookmedicine.edu',
#   'enrollmentcount': '110',
#   'locationstate': 'New York',
#   'latitude': 40.925654,
#   'longitude': -73.140943,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04338126',
#   'brieftitle': 'Tranexamic Acid (TXA) and Corona Virus 2019 (COVID19) in Inpatients',
#   'facility': 'University of Alabama at Birmingham',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Timothy J Ness, MD PhD',
#   'contactphone': '2059079743',
#   'contactemail': 'tness@uabmc.edu',
#   'enrollmentcount': '60',
#   'locationstate': 'Alabama',
#   'latitude': 33.520682,
#   'longitude': -86.802433,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04319731',
#   'brieftitle': 'A Pilot Study of Human Amniotic Fluid for COVID19 Associated Respiratory Failure',
#   'facility': 'University of Utah Health',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Craig Selzman, MD',
#   'contactphone': '(801) 581-5311',
#   'contactemail': 'craig.selzman@hsc.utah.edu',
#   'enrollmentcount': '10',
#   'locationstate': 'Utah',
#   'latitude': 40.77121,
#   'longitude': -111.838608,
#   'phase': 'Early Phase 1'},
#  {'nctid': 'NCT04350450',
#   'brieftitle': 'Hydroxychloroquine Treatment of Healthcare Workers With COVID19 Illness at Montefiore',
#   'facility': 'Montefiore Medical Center',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Priya Nori, MD',
#   'contactphone': '(718) 920-4622',
#   'contactemail': 'pnori@montefiore.org',
#   'enrollmentcount': '100',
#   'locationstate': 'New York',
#   'latitude': 40.857033,
#   'longitude': -73.836696,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04357782',
#   'brieftitle': 'Administration of Intravenous Vitamin C in Novel Coronavirus Infection (COVID-19) and Decreased Oxygenation',
#   'facility': 'Hunter Holmes Mcguire Veteran Affairs Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Brian C Davis, MD',
#   'contactphone': '804-675-5000',
#   'contactemail': 'Brian.Davis5@va.gov',
#   'enrollmentcount': '20',
#   'locationstate': 'Virginia',
#   'latitude': 37.538509,
#   'longitude': -77.43428,
#   'phase': 'Phase 1'},
#  {'nctid': 'NCT04357782',
#   'brieftitle': 'Administration of Intravenous Vitamin C in Novel Coronavirus Infection (COVID-19) and Decreased Oxygenation',
#   'facility': 'Hunter Holmes Mcguire Veteran Affairs Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Brian C Davis, MD',
#   'contactphone': '804-675-5000',
#   'contactemail': 'Brian.Davis5@va.gov',
#   'enrollmentcount': '20',
#   'locationstate': 'Virginia',
#   'latitude': 37.538509,
#   'longitude': -77.43428,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04336332',
#   'brieftitle': 'Randomized Comparison of Combination Azithromycin and Hydroxychloroquine vs. Hydroxychloroquine Alone for the Treatment of Confirmed COVID-19',
#   'facility': 'Robert Wood Johnson University Hopsital',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Sabiha Hussain, MD',
#   'contactphone': '732-235-7840',
#   'contactemail': 'hussaisa@rwjms.rutgers.edu',
#   'enrollmentcount': '160',
#   'locationstate': 'New Jersey',
#   'latitude': 40.49363,
#   'longitude': -74.438394,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04359901',
#   'brieftitle': 'Sarilumab for Patients With Moderate COVID-19 Disease: A Randomized Controlled Trial With a Play-The-Winner Design',
#   'facility': 'VA Boston Healthcare System',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Sara Schiller, MPH',
#   'contactphone': '857-364-2012',
#   'contactemail': 'Sara.Schiller1@va.gov',
#   'enrollmentcount': '120',
#   'locationstate': 'Massachusetts',
#   'latitude': 42.360253,
#   'longitude': -71.058291,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04349371',
#   'brieftitle': 'Saved From COVID-19',
#   'facility': 'Columbia University Irving Medical Center/NYP',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Anca D. Askanase, MD, MPH',
#   'contactphone': '212-305-0856',
#   'contactemail': 'ada20@cumc.columbia.edu',
#   'enrollmentcount': '350',
#   'locationstate': 'New York',
#   'latitude': 40.730646,
#   'longitude': -73.986614,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04336410',
#   'brieftitle': 'Safety, Tolerability and Immunogenicity of INO-4800 for COVID-19 in Healthy Volunteers',
#   'facility': 'Center for Pharmaceutical Research',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Inovio Call Center',
#   'contactphone': '(267) 440-4237',
#   'contactemail': 'clinical.trials@inovio.com',
#   'enrollmentcount': '40',
#   'locationstate': 'Missouri',
#   'latitude': 38.931189,
#   'longitude': -94.590322,
#   'phase': 'Phase 1'},
#  {'nctid': 'NCT04312009',
#   'brieftitle': 'Losartan for Patients With COVID-19 Requiring Hospitalization',
#   'facility': 'Hennepin County Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Christopher Tignanelli, MD',
#   'contactphone': '612-624-4373',
#   'contactemail': 'Covid19trial@umn.edu',
#   'enrollmentcount': '200',
#   'locationstate': 'Minnesota',
#   'latitude': 44.9773,
#   'longitude': -93.265469,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04345614',
#   'brieftitle': 'A Study of CM4620-Injectable Emulsion (IE) in Patients With Severe COVID-19 Pneumonia',
#   'facility': 'Henry Ford Hospital',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Sudarshan Hebbar, MD',
#   'contactphone': '816-838-7105',
#   'contactemail': 'sudarshan@calcimedica.com',
#   'enrollmentcount': '120',
#   'locationstate': 'Michigan',
#   'latitude': 39.78373,
#   'longitude': -100.445882,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04306393',
#   'brieftitle': 'Nitric Oxide Gas Inhalation in Severe Acute Respiratory Syndrome in COVID-19',
#   'facility': 'University of Alabama',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Lorenzo Berra, MD',
#   'contactphone': '+16176437733',
#   'contactemail': 'lberra@mgh.harvard.edu',
#   'enrollmentcount': '200',
#   'locationstate': 'Alabama',
#   'latitude': 33.520682,
#   'longitude': -86.802433,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04361552',
#   'brieftitle': 'Tocilizumab for the Treatment of Cytokine Release Syndrome in Patients With COVID-19 (SARS-CoV-2 Infection)',
#   'facility': 'Emory University Hospital/Winship Cancer Institute',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Shondolyn D. Richburg',
#   'contactphone': '4047783612',
#   'contactemail': 'shondolyn.k.richburg@emory.edu',
#   'enrollmentcount': '180',
#   'locationstate': 'Georgia',
#   'latitude': 33.749099,
#   'longitude': -84.390185,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04283461',
#   'brieftitle': 'Safety and Immunogenicity Study of 2019-nCoV Vaccine (mRNA-1273) for Prophylaxis SARS CoV-2 Infection (COVID-19)',
#   'facility': 'Emory Vaccine Center - The Hope Clinic',
#   'overallstatus': 'Recruiting',
#   'contactname': '20-0003 Central Contact',
#   'contactphone': '12062872061',
#   'contactemail': 'KPWA.vaccine@kp.org',
#   'enrollmentcount': '45',
#   'locationstate': 'Georgia',
#   'latitude': 39.78373,
#   'longitude': -100.445882,
#   'phase': 'Phase 1'},
#  {'nctid': 'NCT04341441',
#   'brieftitle': 'Will Hydroxychloroquine Impede or Prevent COVID-19',
#   'facility': 'Henry Ford Hospital',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Dee Dee Wang, MD',
#   'contactphone': '313-574-2651',
#   'contactemail': 'whipcovid19@hfhs.org',
#   'enrollmentcount': '3000',
#   'locationstate': 'Michigan',
#   'latitude': 39.78373,
#   'longitude': -100.445882,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04341727',
#   'brieftitle': 'Hydroxychloroquine,Hydroxychloroquine,Azithromycin in the Treatment of SARS CoV-2 Infection',
#   'facility': 'Washington University School of Medicine Infectious Disease Clinical Research Unit',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Michael Klebert, RN PhD',
#   'contactphone': '314 747 1098',
#   'contactemail': 'mklebert@wustl.edu',
#   'enrollmentcount': '500',
#   'locationstate': 'Missouri',
#   'latitude': 38.622445,
#   'longitude': -90.257051,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04311177',
#   'brieftitle': 'Losartan for Patients With COVID-19 Not Requiring Hospitalization',
#   'facility': 'Hennepin County Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Christopher Tignanelli, MD',
#   'contactphone': '612-624-4373',
#   'contactemail': 'Covid19trial@umn.edu',
#   'enrollmentcount': '580',
#   'locationstate': 'Minnesota',
#   'latitude': 44.9773,
#   'longitude': -93.265469,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04335552',
#   'brieftitle': 'Pragmatic Factorial Trial of Hydroxychloroquine, Azithromycin, or Both for Treatment of Severe SARS-CoV-2 Infection',
#   'facility': 'Duke Regional Hospital',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Jason Stout, MD',
#   'contactphone': '919-668-0826',
#   'contactemail': 'jason.stout@dm.duke.edu',
#   'enrollmentcount': '500',
#   'locationstate': 'North Carolina',
#   'latitude': 39.78373,
#   'longitude': -100.445882,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04311697',
#   'brieftitle': 'Intravenous Aviptadil for COVID-19 Associated Acute Respiratory Distress',
#   'facility': 'Miller School of Medicine / University of Miami Medical Center',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Robert E Besthof, MIM',
#   'contactphone': '+14842546134',
#   'contactemail': 'rbesthof@neurorxpharma.com',
#   'enrollmentcount': '120',
#   'locationstate': 'Florida',
#   'latitude': 25.774266,
#   'longitude': -80.193659,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04322682',
#   'brieftitle': 'Colchicine Coronavirus SARS-CoV2 Trial (COLCORONA)',
#   'facility': 'University of California, San Francisco - San Francisco General Hospital',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Jean-Claude Tardif, MD',
#   'contactphone': '514-376-3330',
#   'contactemail': 'jean-claude.tardif@icm-mhi.org',
#   'enrollmentcount': '6000',
#   'locationstate': 'California',
#   'latitude': 37.779281,
#   'longitude': -122.419236,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04340557',
#   'brieftitle': 'Do Angiotensin Receptor Blockers Mitigate Progression to Acute Respiratory Distress Syndrome With SARS-CoV-2 Infection',
#   'facility': 'Sharp Grossmont Hospital',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Katie Miller',
#   'contactphone': '(858) 939-7162',
#   'contactemail': 'kathryn.miller@sharp.com',
#   'enrollmentcount': '200',
#   'locationstate': 'California',
#   'latitude': 32.767829,
#   'longitude': -117.023084,
#   'phase': 'Phase 4'},
#  {'nctid': 'NCT04341116',
#   'brieftitle': 'Study of TJ003234 (Anti-GM-CSF Monoclonal Antibody) in Subjects With Severe Coronavirus Disease 2019 (COVID-19)',
#   'facility': 'OSF Healthcare Saint Francis Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'US Site Head',
#   'contactphone': '240-767-6981',
#   'contactemail': 'US.Info@I-MabBiopharma.com',
#   'enrollmentcount': '144',
#   'locationstate': 'Illinois',
#   'latitude': 40.693861,
#   'longitude': -89.589101,
#   'phase': 'Phase 1'},
#  {'nctid': 'NCT04341116',
#   'brieftitle': 'Study of TJ003234 (Anti-GM-CSF Monoclonal Antibody) in Subjects With Severe Coronavirus Disease 2019 (COVID-19)',
#   'facility': 'OSF Healthcare Saint Francis Medical Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'US Site Head',
#   'contactphone': '240-767-6981',
#   'contactemail': 'US.Info@I-MabBiopharma.com',
#   'enrollmentcount': '144',
#   'locationstate': 'Illinois',
#   'latitude': 40.693861,
#   'longitude': -89.589101,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04333654',
#   'brieftitle': 'Hydroxychloroquine in Outpatient Adults With COVID-19',
#   'facility': 'Investigational Site Number 8400001',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Trial Transparency email recommended (Toll free number for US & Canada)',
#   'contactphone': '800-633-1610',
#   'contactemail': 'Contact-US@sanofi.com',
#   'enrollmentcount': '210',
#   'locationstate': 'Massachusetts',
#   'latitude': 42.360253,
#   'longitude': -71.058291,
#   'phase': 'Phase 1'},
#  {'nctid': 'NCT04349332',
#   'brieftitle': 'Early Extubation for Patients With Acute Hypoxemic Respiratory Failure',
#   'facility': 'University of Chicago Medical Center',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Bhakti Patel, MD',
#   'contactphone': '773-702-6800',
#   'contactemail': 'bpatel@medicine.bsd.uchicago.edu',
#   'enrollmentcount': '108',
#   'locationstate': 'Illinois',
#   'latitude': 41.875555,
#   'longitude': -87.624421,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04308668',
#   'brieftitle': 'Post-exposure Prophylaxis / Preemptive Therapy for SARS-Coronavirus-2',
#   'facility': 'Nationwide Enrollment via Internet, please email: covid19@umn.edu',
#   'overallstatus': 'Recruiting',
#   'contactname': 'David Boulware (Please email), MD, MPH',
#   'contactphone': '6126249996',
#   'contactemail': 'covid19@umn.edu',
#   'enrollmentcount': '3000',
#   'locationstate': 'Minnesota',
#   'latitude': 44.9773,
#   'longitude': -93.265469,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04348370',
#   'brieftitle': 'BCG Vaccine for Health Care Workers as Defense Against SARS-COV2',
#   'facility': 'Harvard T.H. Chan School of Public Health',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Andrew DiNardo, MD',
#   'contactphone': '832-822-1038',
#   'contactemail': 'Andrew.Dinardo@Bcm.Edu',
#   'enrollmentcount': '700',
#   'locationstate': 'Massachusetts',
#   'latitude': 42.360253,
#   'longitude': -71.058291,
#   'phase': 'Phase 4'},
#  {'nctid': 'NCT04328961',
#   'brieftitle': 'Hydroxychloroquine for COVID-19 PEP',
#   'facility': 'University of California Los Angeles',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Meighan Krows',
#   'contactphone': '206-520-3833',
#   'contactemail': 'meigs@uw.edu',
#   'enrollmentcount': '2000',
#   'locationstate': 'California',
#   'latitude': 34.054935,
#   'longitude': -118.244476,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04328961',
#   'brieftitle': 'Hydroxychloroquine for COVID-19 PEP',
#   'facility': 'University of California Los Angeles',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Meighan Krows',
#   'contactphone': '206-520-3833',
#   'contactemail': 'meigs@uw.edu',
#   'enrollmentcount': '2000',
#   'locationstate': 'California',
#   'latitude': 34.054935,
#   'longitude': -118.244476,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04315298',
#   'brieftitle': 'Evaluation of the Efficacy and Safety of Sarilumab in Hospitalized Patients With COVID-19',
#   'facility': 'Regeneron Study Site',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Clinical Trials Administrator',
#   'contactphone': '844-734-6643',
#   'contactemail': 'clinicaltrials@regeneron.com',
#   'enrollmentcount': '400',
#   'locationstate': 'California',
#   'latitude': 34.054935,
#   'longitude': -118.244476,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04315298',
#   'brieftitle': 'Evaluation of the Efficacy and Safety of Sarilumab in Hospitalized Patients With COVID-19',
#   'facility': 'Regeneron Study Site',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Clinical Trials Administrator',
#   'contactphone': '844-734-6643',
#   'contactemail': 'clinicaltrials@regeneron.com',
#   'enrollmentcount': '400',
#   'locationstate': 'California',
#   'latitude': 34.054935,
#   'longitude': -118.244476,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04317040',
#   'brieftitle': 'CD24Fc as a Non-antiviral Immunomodulator in COVID-19 Treatment',
#   'facility': 'Baptist Health Research Institute',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Pan Zheng, MD, PhD',
#   'contactphone': '(202) 7516823',
#   'contactemail': 'pzheng@oncoimmune.com',
#   'enrollmentcount': '230',
#   'locationstate': 'Florida',
#   'latitude': 30.332184,
#   'longitude': -81.655651,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04292899',
#   'brieftitle': 'Study to Evaluate the Safety and Antiviral Activity of Remdesivir (GS-5734™) in Participants With Severe Coronavirus Disease (COVID-19)',
#   'facility': 'Kaiser Permanente Los Angeles Medical Center, 3340 E. La Palma Avenue',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Gilead Clinical Study Information Center',
#   'contactphone': '1-833-445-3230 (GILEAD-0)',
#   'contactemail': 'GileadClinicalTrials@gilead.com',
#   'enrollmentcount': '6000',
#   'locationstate': 'California',
#   'latitude': 33.847751,
#   'longitude': -117.877454,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04292730',
#   'brieftitle': 'Study to Evaluate the Safety and Antiviral Activity of Remdesivir (GS-5734™) in Participants With Moderate Coronavirus Disease (COVID-19) Compared to Standard of Care Treatment',
#   'facility': 'Kaiser Permanente Los Angeles Medical Center, 3340 E. La Palma Avenue',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Gilead Clinical Study Information Center',
#   'contactphone': '1-833-445-3230 (GILEAD-0)',
#   'contactemail': 'GileadClinicalTrials@gilead.com',
#   'enrollmentcount': '1600',
#   'locationstate': 'California',
#   'latitude': 33.847751,
#   'longitude': -117.877454,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04320615',
#   'brieftitle': 'A Study to Evaluate the Safety and Efficacy of Tocilizumab in Patients With Severe COVID-19 Pneumonia',
#   'facility': 'University of California San Diego',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Reference Study ID Number: WA42380 www.roche.com/about_roche/roche_worldwide.htm',
#   'contactphone': '888-662-6728',
#   'contactemail': 'global-roche-genentech-trials@gene.com',
#   'enrollmentcount': '330',
#   'locationstate': 'California',
#   'latitude': 32.833501,
#   'longitude': -117.26162,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04332991',
#   'brieftitle': 'Outcomes Related to COVID-19 Treated With Hydroxychloroquine Among In-patients With Symptomatic Disease',
#   'facility': 'University of Arizona',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Katie Oldmixon, RN',
#   'contactphone': '617 726-4777',
#   'contactemail': 'coldmixon@mgh.harvard.edu',
#   'enrollmentcount': '510',
#   'locationstate': 'Arizona',
#   'latitude': 32.221892,
#   'longitude': -110.926235,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT03808922',
#   'brieftitle': 'Phase III DAS181 Lower Tract PIV Infection in Immunocompromised Subjects (Substudy: DAS181 for COVID-19): RCT Study',
#   'facility': 'City of Hope cancer Center',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Jennifer Ho, M.D',
#   'contactphone': '858-452-2631',
#   'contactemail': 'jho@ansunbiopharma.com',
#   'enrollmentcount': '250',
#   'locationstate': 'California',
#   'latitude': 34.139451,
#   'longitude': -117.977287,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT04349098',
#   'brieftitle': 'Evaluation of Activity and Safety of Oral Selinexor in Participants With Severe COVID-19 Infection',
#   'facility': 'UCLA',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Jatin Shah, Chief Medical Officer',
#   'contactphone': '(617) 658-0600',
#   'contactemail': 'jshah@karyopharm.com',
#   'enrollmentcount': '230',
#   'locationstate': 'California',
#   'latitude': 34.054935,
#   'longitude': -118.244476,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT04280705',
#   'brieftitle': 'Adaptive COVID-19 Treatment Trial (ACTT)',
#   'facility': 'University of Alabama at Birmingham School of Medicine - Infectious Disease',
#   'overallstatus': 'Recruiting',
#   'contactname': '20-0006 Central Contact',
#   'contactphone': '13017617948',
#   'contactemail': 'DMIDClinicalTrials@niaid.nih.gov',
#   'enrollmentcount': '572',
#   'locationstate': 'Alabama',
#   'latitude': 33.520682,
#   'longitude': -86.802433,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT03710746',
#   'brieftitle': 'Project Health: Enhancing Effectiveness of a Dissonance-Based Obesity Prevention Program',
#   'facility': 'Oregon Research Institute',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Eric M Stice, Ph.D.',
#   'contactphone': '541-484-2123',
#   'contactemail': 'estice@ori.org',
#   'enrollmentcount': '450',
#   'locationstate': 'Oregon',
#   'latitude': 44.050505,
#   'longitude': -123.095051,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04173663',
#   'brieftitle': 'Advocating for Supports to Improve Service Transitions',
#   'facility': 'University of Illinois at Urbana-Champaign',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Julie Lounds Taylor, PhD',
#   'contactphone': '615-343-5659',
#   'contactemail': 'julie.l.taylor@vumc.org',
#   'enrollmentcount': '180',
#   'locationstate': 'Illinois',
#   'latitude': 41.875555,
#   'longitude': -87.624421,
#   'phase': 'Not Applicable'},
#  {'nctid': 'NCT04333732',
#   'brieftitle': 'CROWN CORONATION: Chloroquine RepurpOsing to healthWorkers for Novel CORONAvirus mitigaTION',
#   'facility': 'Washington University School of Medicine',
#   'overallstatus': 'Not yet recruiting',
#   'contactname': 'Linda Yun, BS',
#   'contactphone': '314-273-2240',
#   'contactemail': 'lindayun@wustl.edu',
#   'enrollmentcount': '55000',
#   'locationstate': 'Missouri',
#   'latitude': 38.622445,
#   'longitude': -90.257051,
#   'phase': 'Phase 3'},
#  {'nctid': 'NCT03323463',
#   'brieftitle': 'Major De-escalation to 30 Gy for Select Human Papillomavirus Associated Oropharyngeal Carcinoma',
#   'facility': 'Memoral Sloan Kettering Basking Ridge',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Nancy Lee, MD',
#   'contactphone': '212-639-3341',
#   'contactemail': 'leen2@mskcc.org',
#   'enrollmentcount': '300',
#   'locationstate': 'New Jersey',
#   'latitude': 40.706794,
#   'longitude': -74.548569,
#   'phase': 'Phase 2'},
#  {'nctid': 'NCT02915198',
#   'brieftitle': 'Investigation of Metformin in Pre-Diabetes on Atherosclerotic Cardiovascular OuTcomes',
#   'facility': 'Phoenix VA Health Care System, Phoenix, AZ',
#   'overallstatus': 'Recruiting',
#   'contactname': 'Gregory G Schwartz, PhD MD',
#   'contactphone': '(720) 723-6070',
#   'contactemail': 'Gregory.Schwartz@va.gov',
#   'enrollmentcount': '7868',
#   'locationstate': 'Arizona',
#   'latitude': 33.448587,
#   'longitude': -112.077346,
#   'phase': 'Phase 4'}]
